# %% [markdown]
# # BLU02 - Learning Notebook - Data wrangling workflows - Part 1 of 3

# %%
import numpy as np
import pandas as pd
import os

from sklearn.datasets import load_iris

# %% [markdown]
# # About the BLU
#
# ## Data wrangling workflows
#
# A typical data science workflow goes as follows: you get data from a source, you clean it, and then you continuously iterate on it.
#
# ![data_transformation_workflow](./media/data_processing_workflow.png)
#
# On the previous learning unit in this specialization, we focused mostly on getting and cleaning data (the blue boxes above).
#
# At this point, we got a dataset and performed necessary data cleaning. Our data is, therefore, in an interim state:
# * You have a *tidy dataset* (observations as rows and features as columns), comprised of one or more tables
# * You know how to import such tables into Pandas, regardless of the format they are stored.
#
# Now, to explore, visualize and model the data, we have to perform transformations on it with agility, balancing:
# * Speed of iteration, testing different hypothesis fast and easy
# * Consistency, ensuring our pipeline doesn't collapse along the way.
#
# In this first part, we'll go into how to transform the dataset and explore it in Pandas.
#
# Then, we'll zoom in on a how to combine dataframes.
#
# Finally, we'll move to scikit-learn to build efficient pipelines for modeling.

# %% [markdown]
# # About the data
#
# The New York Philharmonic played its first concert on December 7, 1842.
#
# The data documents all known concerts, amounting to more than 20,000 performances. Some considerations:
# * The Program is the top-most level element in the dataset
# * A Program is defined as performances in which the repertoire, conductors, and soloists are the same
# * A Program is associated with an Orchestra (e.g., New York Philharmonic) and a Season (e.g., 1842-43)
# * A Program may have multiple Concerts with different dates, times and locations
# * A Program's repertoire may contain various Works (e.g., two different symphonies by Beethoven)
# * A Work can have multiple Soloists (e.g., Mahler on the harpsichord, Strauss or Bernstein on the piano).
#
# **For more information about the dataset, including the data dictionary, please head to the README.**
#
# In this unit, we will be using Works and Concerts, imported as follows.

# %%
works = pd.read_csv('./data/works.csv')
concerts = pd.read_csv('./data/concerts.csv')

# %%
works.head()
# Out:
#                                    GUID  ProgramID  WorkID  MovementID  \
# 0  38e072a7-8fc9-4f9a-8eac-3957905c0002       3853   52446         NaN
# 1  c7b2b95c-5e0b-431c-a340-5b37fc860b34       5178   52437         NaN
# 2  894e1a52-1ae5-4fa7-aec0-b99997555a37      10785   52364         1.0
# 3  34ec2c2b-3297-4716-9831-b538310462b7       5887   52434         NaN
# 4  610a4acc-94e4-4cd6-bdc1-8ad020edc7e9        305   52453         NaN
#
#               ComposerName                                        WorkTitle  \
# 0  Beethoven,  Ludwig  van                 SYMPHONY NO. 5 IN C MINOR, OP.67
# 1  Beethoven,  Ludwig  van  SYMPHONY NO. 3 IN E FLAT MAJOR, OP. 55 (EROICA)
# 2  Beethoven,  Ludwig  van                                    EGMONT, OP.84
# 3  Beethoven,  Ludwig  van                 SYMPHONY NO. 2 IN D MAJOR, OP.36
# 4  Beethoven,  Ludwig  van                 SYMPHONY NO. 7 IN A MAJOR, OP.92
#
#    Movement        ConductorName Interval
# 0       NaN  Hill, Ureli Corelli      NaN
# 1       NaN  Hill, Ureli Corelli      NaN
# 2  Overture  Hill, Ureli Corelli      NaN
# 3       NaN      Boucher, Alfred      NaN
# 4       NaN  Hill, Ureli Corelli      NaN

# %%
concerts.head()
# Out:
#                                    GUID  ProgramID  ConcertID  \
# 0  38e072a7-8fc9-4f9a-8eac-3957905c0002       3853          0
# 1  c7b2b95c-5e0b-431c-a340-5b37fc860b34       5178          0
# 2  894e1a52-1ae5-4fa7-aec0-b99997555a37      10785          0
# 3  34ec2c2b-3297-4716-9831-b538310462b7       5887          0
# 4  610a4acc-94e4-4cd6-bdc1-8ad020edc7e9        305          0
#
#              EventType       Location         Venue  \
# 0  Subscription Season  Manhattan, NY  Apollo Rooms
# 1  Subscription Season  Manhattan, NY  Apollo Rooms
# 2              Special  Manhattan, NY  Apollo Rooms
# 3  Subscription Season  Manhattan, NY  Apollo Rooms
# 4  Subscription Season  Manhattan, NY  Apollo Rooms
#
#                         Date    Time
# 0  1842-12-07T05:00:00+00:00  8:00PM
# 1  1843-02-18T05:00:00+00:00  8:00PM
# 2  1843-04-07T05:00:00+00:00  8:00PM
# 3  1843-04-22T05:00:00+00:00  8:00PM
# 4  1843-11-18T05:00:00+00:00     NaN

# %%
works.ProgramID.count()
works.ProgramID.nunique()
works.nunique()
works[works.duplicated(subset=['ProgramID', 'WorkID','MovementID'], keep=False)].sort_values(by=['ProgramID', 'WorkID','MovementID'])
# Out:
#                                            GUID  ProgramID  WorkID  \
# 60980      cc889f1b-4283-414b-b1b3-79f354a9c9ab        710       0
# 60981  d5c39c72-0b19-4d69-bf6f-c116fb96a834-0.1        710       0
# 40337      cc889f1b-4283-414b-b1b3-79f354a9c9ab        710    4599
# 40338  d5c39c72-0b19-4d69-bf6f-c116fb96a834-0.1        710    4599
# 14036      cc889f1b-4283-414b-b1b3-79f354a9c9ab        710    4968
# 14037  d5c39c72-0b19-4d69-bf6f-c116fb96a834-0.1        710    4968
# 27369      cc889f1b-4283-414b-b1b3-79f354a9c9ab        710    6709
# 27370  d5c39c72-0b19-4d69-bf6f-c116fb96a834-0.1        710    6709
# 129        cc889f1b-4283-414b-b1b3-79f354a9c9ab        710    8955
# 130    d5c39c72-0b19-4d69-bf6f-c116fb96a834-0.1        710    8955
# 66766      cc889f1b-4283-414b-b1b3-79f354a9c9ab        710   52446
# 66767  d5c39c72-0b19-4d69-bf6f-c116fb96a834-0.1        710   52446
# 52210      cc889f1b-4283-414b-b1b3-79f354a9c9ab        710   52994
# 52211  d5c39c72-0b19-4d69-bf6f-c116fb96a834-0.1        710   52994
# 29658      8f81ef11-c8e5-4d3c-9b82-1533e7714844       1475       0
# 29659  fcc109c1-0b33-4023-9072-9ea7b8b4e466-0.1       1475       0
# 54104      8f81ef11-c8e5-4d3c-9b82-1533e7714844       1475     715
# 54105  fcc109c1-0b33-4023-9072-9ea7b8b4e466-0.1       1475     715
# 2548       8f81ef11-c8e5-4d3c-9b82-1533e7714844       1475    3395
# 2549   fcc109c1-0b33-4023-9072-9ea7b8b4e466-0.1       1475    3395
# 16370      8f81ef11-c8e5-4d3c-9b82-1533e7714844       1475    5550
# 16371  fcc109c1-0b33-4023-9072-9ea7b8b4e466-0.1       1475    5550
# 42510      8f81ef11-c8e5-4d3c-9b82-1533e7714844       1475   50897
# 40337         NaN           Kummer,  Friedrich  August
# 40338         NaN           Kummer,  Friedrich  August
# 14036         NaN                       Rietz,  Julius
# 14037         NaN                       Rietz,  Julius
# 27369        13.0              Weber,  Carl  Maria Von
# 27370        13.0              Weber,  Carl  Maria Von
# 129           1.0           Mozart,  Wolfgang  Amadeus
# 130           1.0           Mozart,  Wolfgang  Amadeus
# 66766         NaN              Beethoven,  Ludwig  van
# 66767         NaN              Beethoven,  Ludwig  van
# 52210         NaN                    Schumann,  Robert
# 52211         NaN                    Schumann,  Robert
# 29658         NaN                                  NaN
# 29659         NaN                                  NaN
# 54104         NaN                      Ravel,  Maurice
# 54105         NaN                      Ravel,  Maurice
# 2548          NaN                     Berlioz,  Hector
# 2549          NaN                     Berlioz,  Hector
# 16370         NaN                   Indy,  Vincent  d'
# 16371         NaN                   Indy,  Vincent  d'
# 42510         NaN            Albeniz [Albéniz],  Isaac
# 42511         NaN            Albeniz [Albéniz],  Isaac
# 16393         NaN                                  NaN
# 16394         NaN                                  NaN
# 29681         NaN              Beethoven,  Ludwig  van
# 29682         NaN              Beethoven,  Ludwig  van
# 2571          NaN                      Mahler,  Gustav
# 2572          NaN                      Mahler,  Gustav
# ...           ...                                  ...
# 27235         NaN                      Barber,  Samuel
# 27236         NaN                      Barber,  Samuel
# 70594         NaN                     Schubert,  Franz
# 70595         NaN                     Schubert,  Franz
# 66658         NaN                     Schubert,  Franz
# 66659         NaN                     Schubert,  Franz
# 52081         6.0                      Copland,  Aaron
# 52082         6.0                      Copland,  Aaron
# 40203         7.0                      Copland,  Aaron
# 40204         7.0                      Copland,  Aaron
# 13901         NaN                       Glass,  Philip
# 13902         NaN                       Glass,  Philip
# 40113         NaN       Faure [Fauré],  Gabriel-Urbain
# 40114         NaN       Faure [Fauré],  Gabriel-Urbain
# 27141         NaN  Saint-Saens [Saint-Saëns],  Camille
# 27142         NaN  Saint-Saens [Saint-Saëns],  Camille
# 13800         1.0            Renie [Renié],  Henriette
# 13801         1.0            Renie [Renié],  Henriette
# 66633         2.0            Renie [Renié],  Henriette
# 66634         2.0            Renie [Renié],  Henriette
# 52014         NaN       Faure [Fauré],  Gabriel-Urbain
# 52015         NaN       Faure [Fauré],  Gabriel-Urbain
# 60815         NaN  Saint-Saens [Saint-Saëns],  Camille
# 60816         NaN  Saint-Saens [Saint-Saëns],  Camille
# 27159         NaN                                  NaN
# 27160         NaN                                  NaN
# 40130         NaN                Shostakovich,  Dmitri
# 40131         NaN                Shostakovich,  Dmitri
# 13818         NaN                   Prokofiev,  Sergei
# 13819         NaN                   Prokofiev,  Sergei
#
#                                                WorkTitle  \
# 60980                                                NaN
# 60981                                                NaN
# 40337                    GRANDE FANTASIE RUSSE FOR CELLO
# 40338                    GRANDE FANTASIE RUSSE FOR CELLO
# 14036                                            QUINTET
# 14037                                            QUINTET
# 27369                                    FREISCHUTZ, DER
# 27370                                    FREISCHUTZ, DER
# 129                              MAGIC FLUTE, THE, K.620
# 130                              MAGIC FLUTE, THE, K.620
# 66766                   SYMPHONY NO. 5 IN C MINOR, OP.67
# 66767                   SYMPHONY NO. 5 IN C MINOR, OP.67
# 52210                          GENOVEVA OVERTURE, OP. 81
# 52211                          GENOVEVA OVERTURE, OP. 81
# 29658                                                NaN
# 29659                                                NaN
# 54104                                          VALSE, LA
# 54105                                          VALSE, LA
# 2548        ROMAN CARNIVAL OVERTURE (LE CARNAVAL ROMAIN)
# 2549        ROMAN CARNIVAL OVERTURE (LE CARNAVAL ROMAIN)
# 16370          SYMPHONY ON A FRENCH MOUNTAIN AIR, OP. 25
# 16371          SYMPHONY ON A FRENCH MOUNTAIN AIR, OP. 25
# 42510                   RAPSODIA ESPANOLA (ARR. Casella)
# 42511                   RAPSODIA ESPANOLA (ARR. Casella)
# 16393                                                NaN
# 16394                                                NaN
# 29681   CONCERTO, VIOLIN, CELLO & PIANO, OP. 56 (TRIPLE)
# 29682   CONCERTO, VIOLIN, CELLO & PIANO, OP. 56 (TRIPLE)
# 2571      SYMPHONY NO.  7 IN E MINOR (SONG OF THE NIGHT)
# 2572      SYMPHONY NO.  7 IN E MINOR (SONG OF THE NIGHT)
# ...                                                  ...
# 27235                         DAISIES, THE, OP. 2, NO. 1
# 27236                         DAISIES, THE, OP. 2, NO. 1
# 70594  QUINTET FOR PIANO AND STRINGS, A MAJOR, D.667 ...
# 70595  QUINTET FOR PIANO AND STRINGS, A MAJOR, D.667 ...
# 66658                                FORELLE, DIE, D.550
# 66659                                FORELLE, DIE, D.550
# 52081               OLD AMERICAN SONGS (VOICE AND PIANO)
# 52082               OLD AMERICAN SONGS (VOICE AND PIANO)
# 40203               OLD AMERICAN SONGS (VOICE AND PIANO)
# 40204               OLD AMERICAN SONGS (VOICE AND PIANO)
# 13901                   QUARTET, STRING, NO. 3 (MISHIMA)
# 13902                   QUARTET, STRING, NO. 3 (MISHIMA)
# 40113                   APRÈS UN RÊVE (TRANS. FOR CELLO)
# 40114                   APRÈS UN RÊVE (TRANS. FOR CELLO)
# 27141                  FANTASY, VIOLIN AND HARP, OP. 124
# 27142                  FANTASY, VIOLIN AND HARP, OP. 124
# 13800            TRIO, VIOLIN, CELLO, HARP, B-FLAT MAJOR
# 13801            TRIO, VIOLIN, CELLO, HARP, B-FLAT MAJOR
# 66633            TRIO, VIOLIN, CELLO, HARP, B-FLAT MAJOR
# 66634            TRIO, VIOLIN, CELLO, HARP, B-FLAT MAJOR
# 52014                            PAPILLON [CELLO] OP. 77
# 52015                            PAPILLON [CELLO] OP. 77
# 60815          CARNIVAL OF THE ANIMALS, THE SWAN [CELLO]
# 60816          CARNIVAL OF THE ANIMALS, THE SWAN [CELLO]
# 27159                                                NaN
# 27160                                                NaN
# 40130                   SYMPHONY NO.  5, D MINOR, OP. 47
# 40131                   SYMPHONY NO.  5, D MINOR, OP. 47
# 13818           CONCERTO, VIOLIN, NO. 2, OP. 63, G MINOR
# 13819           CONCERTO, VIOLIN, NO. 2, OP. 63, G MINOR
#
#                                                 Movement       ConductorName  \
# 60980                                                NaN                 NaN
# 60981                                                NaN                 NaN
# 40337                                                NaN      Bergmann, Carl
# 40338                                                NaN      Bergmann, Carl
# 14036                                                NaN      Bergmann, Carl
# 14037                                                NaN      Bergmann, Carl
# 27369  "Wie nahte mir der Schlummer...Leise, leise, f...      Bergmann, Carl
# 27370  "Wie nahte mir der Schlummer...Leise, leise, f...      Bergmann, Carl
# 129                                             Overture      Bergmann, Carl
# 130                                             Overture      Bergmann, Carl
# 66766                                                NaN      Bergmann, Carl
# 66767                                                NaN      Bergmann, Carl
# 52210                                                NaN      Bergmann, Carl
# 52211                                                NaN      Bergmann, Carl
# 29658                                                NaN                 NaN
# 29659                                                NaN                 NaN
# 54104                                                NaN  Mengelberg, Willem
# 54105                                                NaN  Mengelberg, Willem
# 2548                                                 NaN  Mengelberg, Willem
# 2549                                                 NaN  Mengelberg, Willem
# 16370                                                NaN  Mengelberg, Willem
# 16371                                                NaN  Mengelberg, Willem
# 42510                                                NaN  Mengelberg, Willem
# 42511                                                NaN  Mengelberg, Willem
# 16393                                                NaN                 NaN
# 16394                                                NaN                 NaN
# 29681                                                NaN  Mengelberg, Willem
# 29682                                                NaN  Mengelberg, Willem
# 2571                                                 NaN  Mengelberg, Willem
# 2572                                                 NaN  Mengelberg, Willem
# ...                                                  ...                 ...
# 27235                                                NaN                 NaN
# 27236                                                NaN                 NaN
# 70594                                                NaN                 NaN
# 70595                                                NaN                 NaN
# 66658                                                NaN                 NaN
# 66659                                                NaN                 NaN
# 52081                                    "Long Time Ago"                 NaN
# 52082                                    "Long Time Ago"                 NaN
# 40203                                     "Simple Gifts"                 NaN
# 40204                                     "Simple Gifts"                 NaN
# 13901                                                NaN                 NaN
# 13902                                                NaN                 NaN
# 40113                                                NaN                 NaN
# 40114                                                NaN                 NaN
# 27141                                                NaN                 NaN
# 27142                                                NaN                 NaN
# 13800                                            Andante                 NaN
# 13801                                            Andante                 NaN
# 66633                                   Allegro risoluto                 NaN
# 66634                                   Allegro risoluto                 NaN
# 52014                                                NaN                 NaN
# 52015                                                NaN                 NaN
# 60815                                                NaN                 NaN
# 60816                                                NaN                 NaN
# 27159                                                NaN                 NaN
# 27160                                                NaN                 NaN
# 40130                                                NaN            Yu, Long
# 40131                                                NaN            Yu, Long
# 13818                                                NaN            Yu, Long
# 13819                                                NaN            Yu, Long
#
#            Interval
# 60980  Intermission
# 60981  Intermission
# 40337           NaN
# 40338           NaN
# 14036           NaN
# 14037           NaN
# 27369           NaN
# 27370           NaN
# 129             NaN
# 130             NaN
# 66766           NaN
# 66767           NaN
# 52210           NaN
# 52211           NaN
# 29658  Intermission
# 29659  Intermission
# 54104           NaN
# 54105           NaN
# 2548            NaN
# 2549            NaN
# 16370           NaN
# 16371           NaN
# 42510           NaN
# 42511           NaN
# 16393  Intermission
# 16394  Intermission
# 29681           NaN
# 29682           NaN
# 2571            NaN
# 2572            NaN
# ...             ...
# 27235           NaN
# 27236           NaN
# 70594           NaN
# 70595           NaN
# 66658           NaN
# 66659           NaN
# 52081           NaN
# 52082           NaN
# 40203           NaN
# 40204           NaN
# 13901           NaN
# 13902           NaN
# 40113           NaN
# 40114           NaN
# 27141           NaN
# 27142           NaN
# 13800           NaN
# 13801           NaN
# 66633           NaN
# 66634           NaN
# 52014           NaN
# 52015           NaN
# 60815           NaN
# 60816           NaN
# 27159  Intermission
# 27160  Intermission
# 40130           NaN
# 40131           NaN
# 13818           NaN
# 13819           NaN
#
# [314 rows x 9 columns]

# %% [markdown]
# # 1 Data transformation
#
# ## 1.1 Transformations as functions
#
# Most data transformations operate on dataframes: they receive a local dataframe, transform it and return a new one.
#
# In its simplest form, this is the signature of a generic data transformer.

# %%
def data_transformer(df):
    df = df.copy()
    # df = ...
    return df

# %% [markdown]
# Such transformations have no side effects and operate as functions on immutable data (i.e., they keep the original dataframe unchanged).
#
# Since the output depends only on the arguments, calling them with the same arguments always produces the same result.
#
# Confusing? Not really.

# %%
def rename_column(df, new_name, old_name):
    df = df.copy()
    df[new_name] = df[old_name]
    df = df.drop(columns=old_name)
    return df

def test_dataframe():
    data = np.random.randn(6, 4)
    columns = ['A', 'B', 'C', 'D']
    return pd.DataFrame(data=data, columns=columns)

df = test_dataframe()

rename_column(df, 'Z', 'A')
# Out:
#           B         C         D         Z
# 0 -0.266289  3.082971 -0.941685  1.702371
# 1 -0.905506 -2.106767 -1.597949  0.446181
# 2  0.378139 -0.277844 -0.288708  1.668544
# 3  2.227402  1.516974 -1.970619  0.161969
# 4 -0.112727  0.202026 -0.988840 -0.669036
# 5 -0.758583 -0.818902  0.626686 -2.767385

# %%
rename_column(df, 'Z', 'A')
# Out:
#           B         C         D         Z
# 0 -0.266289  3.082971 -0.941685  1.702371
# 1 -0.905506 -2.106767 -1.597949  0.446181
# 2  0.378139 -0.277844 -0.288708  1.668544
# 3  2.227402  1.516974 -1.970619  0.161969
# 4 -0.112727  0.202026 -0.988840 -0.669036
# 5 -0.758583 -0.818902  0.626686 -2.767385

# %% [markdown]
# The same result, see! The program (or Notebook) remembers nothing but the original data and the function itself: a white canvas!
#
# What about the original dataframe?

# %%
df
# Out:
#           A         B         C         D
# 0  1.702371 -0.266289  3.082971 -0.941685
# 1  0.446181 -0.905506 -2.106767 -1.597949
# 2  1.668544  0.378139 -0.277844 -0.288708
# 3  0.161969  2.227402  1.516974 -1.970619
# 4 -0.669036 -0.112727  0.202026 -0.988840
# 5 -2.767385 -0.758583 -0.818902  0.626686

# %% [markdown]
# After each call, the program *state* is the same as it was before (no new objects, no changes, no nothing!), as if nothing happened.
#
# This property is valid for as long as we don't explicitly overwrite the original dataframe outside the function, using an assignment.

# %%
df = test_dataframe()
df = rename_column(df, 'Z', 'A')

try:
    rename_column(df, 'Z', 'A')
except:
    print("For some reason this doesn't work. Why is that?")
# Out:
# For some reason this doesn't work. Why is that?

# %% [markdown]
# Mutable data is dangerous because it makes programs unpredictable. And this is why you should avoid modifying objects after creation.
#
# Such pitfall is common in Notebooks, especially when you re-run cells, run them in a different order or restart the Kernel. (Am I right?)
#
# **Data transformation is a *pipeline***
#
# Another problem is that data transformation is about applying multiple, sequential changes to the data (i.e., a multistep process).
#
# ![data_transformation_pipeline](./media/data_transformation_pipeline.png)
#
# *Fig 2. - A data transformation pipeline is a multistep process.*
#
# And once we realize this, how do we go about it?

# %%
df = test_dataframe()

df_renamed = rename_column(df, 'Z', 'A')
# Code happens. Ideas are tested, hours go by.
df_renamed_without_b = df_renamed.drop(columns='B')
# More code happens. We keep on testing ideas, days go by.
df_renamed_without_b_positive = df_renamed_without_b[df_renamed_without_b > 0]
# There's a lot of code. Ideas come and go, we've been doing this for a week.
df_renamed_without_b_positive_no_nans = df_renamed_without_b_positive.dropna(how='all')
# Can we honestly trace back how to get from df to here? Probably not.
df_renamed_without_b_positive_no_nans
# Out:
#           C         D         Z
# 0       NaN       NaN  0.803130
# 1  0.055710  0.836145  0.885018
# 2       NaN  1.021075  1.185117
# 3       NaN       NaN  1.395096
# 4  1.059134       NaN  1.024389
# 5  0.820107       NaN       NaN

# %% [markdown]
# Using functions instead, you concisely encapsulate everything.
#
# (Also, you spend less time naming things, unless you want to.)

# %%
def data_transformer(df, how_to_dropna):
    df = df.copy()
    df = rename_column(df, 'Z', 'A')
    df = df.drop(columns='B')
    df = df[df > 0]
    df = df.dropna(how=how_to_dropna)
    return df

data_transformer(df, how_to_dropna='all')
# Out:
#           C         D         Z
# 0       NaN       NaN  0.803130
# 1  0.055710  0.836145  0.885018
# 2       NaN  1.021075  1.185117
# 3       NaN       NaN  1.395096
# 4  1.059134       NaN  1.024389
# 5  0.820107       NaN       NaN

# %% [markdown]
# This function is a bad one: names are not explicit, and there are no apparent blocks of logic.
#
# Functions should organize and document our codebase (*what* you are doing and how).
#
# Using functions, immutable data and avoiding side effects is a smart choice to manage complexity and keep things understandable.
#
# Alternatively, we could structure our functions more like this.

# %%
def preprocess_data():
    df = df.copy()
    # df = rename_misspelled_columns(df)
    # df = drop_unnecessary_columns(df)
    # df = keep_only_positive_values(df)
    # df = removemissing_values(df)
    return df

# %% [markdown]
# ## 1.2 Data transformation in Pandas
#
# Pandas provides convenient methods for most data transformation tasks, with a unified, well-known syntax and consistent interfaces.
#
# For example, we don't need to create a `rename_column()` function, since Pandas already provides a `df.rename()` method for us.

# %%
df = test_dataframe()

df.rename({'A': 'Z'}, axis=1)
# Out:
#           Z         B         C         D
# 0  0.598193 -0.967271 -0.980052 -0.878503
# 1  0.831445  1.081508 -0.836292 -0.578561
# 2  0.212106  0.399507 -1.330149  0.348545
# 3  1.651449  0.286606  0.757990 -1.100310
# 4 -0.789647 -0.086643  1.371210  0.028979
# 5 -0.131002  0.226395 -0.538640 -0.819787

# %% [markdown]
# As a recap: `df.rename()` follows our transformer signature:
# * It takes a dataframe as input
# * And returns a new one as output.
#
# This predictable input/output is what we mean by consistent interfaces!
#
# It seems very promising to build and multistep pipelines, no? What transformations can we perform this way?

# %% [markdown]
# ### 1.2.1 Subsetting columns or the index
#
# #### Take a subset of indexes or columns
#
# Pandas implements this functionality, somewhat counterintuitively, as `df.filter()`.
#
# Imagine that we want only the columns related to the work itself, excluding IDs.

# %%
work_related_columns = ['ComposerName', 'WorkTitle', 'Movement']
# Select columns by name.
works.filter(items=work_related_columns).head()
# Out:
#               ComposerName                                        WorkTitle  \
# 0  Beethoven,  Ludwig  van                 SYMPHONY NO. 5 IN C MINOR, OP.67
# 1  Beethoven,  Ludwig  van  SYMPHONY NO. 3 IN E FLAT MAJOR, OP. 55 (EROICA)
# 2  Beethoven,  Ludwig  van                                    EGMONT, OP.84
# 3  Beethoven,  Ludwig  van                 SYMPHONY NO. 2 IN D MAJOR, OP.36
# 4  Beethoven,  Ludwig  van                 SYMPHONY NO. 7 IN A MAJOR, OP.92
#
#    Movement
# 0       NaN
# 1       NaN
# 2  Overture
# 3       NaN
# 4       NaN

# %% [markdown]
# We can also use it to subset our dataframe based on the index.

# %%
# Select rows containing 'Glass' on the index.
works.set_index('ComposerName').filter(like='Glass', axis=0).reset_index().head()
# Out:
#      ComposerName                                      GUID  ProgramID  \
# 0  Glass,  Philip      cf230066-2cd2-4093-8b78-b91b8dda3cbf      11639
# 1  Glass,  Philip      adf68bf5-db9d-4b24-aac6-c9b7c398cf06      14047
# 2  Glass,  Philip  990a8f66-cd5f-466e-b3b6-800baa6c0b47-0.1      14189
# 3  Glass,  Philip      3d50968c-2e8b-405f-969c-ba36f941f393      14189
# 4  Glass,  Philip      fb8e7125-7ef9-492e-a820-914467475701      14025
#
#    WorkID  MovementID                                   WorkTitle Movement  \
# 0    5729         NaN                               KOYAANISQATSI      NaN
# 1   12401         NaN  "FATHER DEATH BLUES" FROM HYDROGEN JUKEBOX      NaN
# 2   12547         NaN            QUARTET, STRING, NO. 3 (MISHIMA)      NaN
# 3   12547         NaN            QUARTET, STRING, NO. 3 (MISHIMA)      NaN
# 4   12327         NaN      SARABANDE IN COMMON TIME (SOLO VIOLIN)      NaN
#
#             ConductorName Interval
# 0        Riesman, Michael      NaN
# 1  Sainte-Agathe, Valérie      NaN
# 2                     NaN      NaN
# 3                     NaN      NaN
# 4                     NaN      NaN

# %%
# Select rows containing 'Glass' on the index.
works.set_index('ComposerName').filter(like='Glass', axis=0).reset_index()
# Out:
#      ComposerName                                      GUID  ProgramID  \
# 0  Glass,  Philip      cf230066-2cd2-4093-8b78-b91b8dda3cbf      11639
# 1  Glass,  Philip      adf68bf5-db9d-4b24-aac6-c9b7c398cf06      14047
# 2  Glass,  Philip  990a8f66-cd5f-466e-b3b6-800baa6c0b47-0.1      14189
# 3  Glass,  Philip      3d50968c-2e8b-405f-969c-ba36f941f393      14189
# 4  Glass,  Philip      fb8e7125-7ef9-492e-a820-914467475701      14025
# 5  Glass,  Philip      70857ba1-11aa-44d1-b58e-dbc252899758      13985
#
#    WorkID  MovementID                                   WorkTitle  \
# 0    5729         NaN                               KOYAANISQATSI
# 1   12401         NaN  "FATHER DEATH BLUES" FROM HYDROGEN JUKEBOX
# 2   12547         NaN            QUARTET, STRING, NO. 3 (MISHIMA)
# 3   12547         NaN            QUARTET, STRING, NO. 3 (MISHIMA)
# 4   12327         NaN      SARABANDE IN COMMON TIME (SOLO VIOLIN)
# 5   12547         1.0            QUARTET, STRING, NO. 3 (MISHIMA)
#
#               Movement           ConductorName Interval
# 0                  NaN        Riesman, Michael      NaN
# 1                  NaN  Sainte-Agathe, Valérie      NaN
# 2                  NaN                     NaN      NaN
# 3                  NaN                     NaN      NaN
# 4                  NaN                     NaN      NaN
# 5  1957: Award Montage                     NaN      NaN

# %%
works['ComposerName'].str.contains('Glass').value_counts(dropna=False)
#works['ComposerName'].str.contains('Glass').fillna(value=False).value_counts(dropna=False)
#works['ComposerName'].describe()
# Out:
# False    71290
# NaN      11280
# True         6
# Name: ComposerName, dtype: int64

# %%
works['ComposerName'].str.contains('Glass').fillna(value=False).value_counts(dropna=False)
composer_filter = works['ComposerName'].str.contains('Glass').fillna(value=False)
works[composer_filter]
# Out:
#                                            GUID  ProgramID  WorkID  \
# 13101      cf230066-2cd2-4093-8b78-b91b8dda3cbf      11639    5729
# 13758      adf68bf5-db9d-4b24-aac6-c9b7c398cf06      14047   12401
# 13901  990a8f66-cd5f-466e-b3b6-800baa6c0b47-0.1      14189   12547
# 13902      3d50968c-2e8b-405f-969c-ba36f941f393      14189   12547
# 40060      fb8e7125-7ef9-492e-a820-914467475701      14025   12327
# 40106      70857ba1-11aa-44d1-b58e-dbc252899758      13985   12547
#
#        MovementID    ComposerName                                   WorkTitle  \
# 13101         NaN  Glass,  Philip                               KOYAANISQATSI
# 13758         NaN  Glass,  Philip  "FATHER DEATH BLUES" FROM HYDROGEN JUKEBOX
# 13901         NaN  Glass,  Philip            QUARTET, STRING, NO. 3 (MISHIMA)
# 13902         NaN  Glass,  Philip            QUARTET, STRING, NO. 3 (MISHIMA)
# 40060         NaN  Glass,  Philip      SARABANDE IN COMMON TIME (SOLO VIOLIN)
# 40106         1.0  Glass,  Philip            QUARTET, STRING, NO. 3 (MISHIMA)
#
#                   Movement           ConductorName Interval
# 13101                  NaN        Riesman, Michael      NaN
# 13758                  NaN  Sainte-Agathe, Valérie      NaN
# 13901                  NaN                     NaN      NaN
# 13902                  NaN                     NaN      NaN
# 40060                  NaN                     NaN      NaN
# 40106  1957: Award Montage                     NaN      NaN

# %%
71290+11280
# Out:
# 82570

# %% [markdown]
# ### 1.2.2 Drop columns
#
# Additionally, `GUID` and `ProgramID` are pretty redundant. We can get rid of `GUID`.

# %%
works.drop(columns='GUID').head()
# Out:
#    ProgramID  WorkID  MovementID             ComposerName  \
# 0       3853   52446         NaN  Beethoven,  Ludwig  van
# 1       5178   52437         NaN  Beethoven,  Ludwig  van
# 2      10785   52364         1.0  Beethoven,  Ludwig  van
# 3       5887   52434         NaN  Beethoven,  Ludwig  van
# 4        305   52453         NaN  Beethoven,  Ludwig  van
#
#                                          WorkTitle  Movement  \
# 0                 SYMPHONY NO. 5 IN C MINOR, OP.67       NaN
# 1  SYMPHONY NO. 3 IN E FLAT MAJOR, OP. 55 (EROICA)       NaN
# 2                                    EGMONT, OP.84  Overture
# 3                 SYMPHONY NO. 2 IN D MAJOR, OP.36       NaN
# 4                 SYMPHONY NO. 7 IN A MAJOR, OP.92       NaN
#
#          ConductorName Interval
# 0  Hill, Ureli Corelli      NaN
# 1  Hill, Ureli Corelli      NaN
# 2  Hill, Ureli Corelli      NaN
# 3      Boucher, Alfred      NaN
# 4  Hill, Ureli Corelli      NaN

# %% [markdown]
# ### 1.2.3 Group By
#
# This is a very extensive topic, and we'll just touch it's surface here, so that you know that exists and can explore it further later by your own.
#
# In case you've worked with SQL before, you'll find this very familiar :)
#
# So, in Pandas there is a process of three chained steps called split-apply-combine:
#
# - split: splitting the DataFrame into groups (this is the groupby), we need to specify the column or the columns that will be used to form the groups.
# - apply: apply a function to each group (aggregation, transformation and filtration)
# - combine: create a DataFrame with the results
#
# With this out of the way, it's time to focus on three types of functions you may want to apply:
# * Aggregation (e.g., sum, count, mean)
# * Transformation (e.g., filling missing values)
# * Filtration (e.g., discard data from underrepresented groups).
#
# We will drill-down into each one of them. For this next part, we will use be using the `concerts` data.

# %% [markdown]
# **Aggregation** (e.g., sum, count, mean)
#
# We want to start by uncovering the most popular programs, by the number of performances.
#
# So the first step is to group our data by `ProgramID`. This returns a DataFrameGroupBy object that by itself doesn't tell us much.
#
# However, we can use the group property of the DataFrameGroupBy object to inspect the groups.

# %%
concerts_grouped_by_ProgramID = concerts.groupby('ProgramID')
concerts_grouped_by_ProgramID

# %%
concerts_grouped_by_ProgramID.groups
# Out:
# {1: Int64Index([474, 14097], dtype='int64'),
#  2: Int64Index([1578], dtype='int64'),
#  3: Int64Index([1579], dtype='int64'),
#  4: Int64Index([1580, 14382], dtype='int64'),
#  5: Int64Index([10075], dtype='int64'),
#  6: Int64Index([1581], dtype='int64'),
#  7: Int64Index([10076, 16815, 19224, 20893], dtype='int64'),
#  8: Int64Index([10066], dtype='int64'),
#  9: Int64Index([9471], dtype='int64'),
#  10: Int64Index([7565], dtype='int64'),
#  11: Int64Index([1582], dtype='int64'),
#  12: Int64Index([10077, 16816, 19225, 20894], dtype='int64'),
#  13: Int64Index([10058], dtype='int64'),
#  14: Int64Index([9473], dtype='int64'),
#  15: Int64Index([7566], dtype='int64'),
#  16: Int64Index([154], dtype='int64'),
#  17: Int64Index([3797, 14812], dtype='int64'),
#  18: Int64Index([1583], dtype='int64'),
#  19: Int64Index([10065], dtype='int64'),
#  20: Int64Index([10078, 16817, 19226], dtype='int64'),
#  21: Int64Index([9475], dtype='int64'),
#  22: Int64Index([7567, 15738], dtype='int64'),
#  24: Int64Index([1584], dtype='int64'),
#  25: Int64Index([10063], dtype='int64'),
#  26: Int64Index([10433], dtype='int64'),
#  27: Int64Index([7568], dtype='int64'),
#  28: Int64Index([1585, 14383], dtype='int64'),
#  29: Int64Index([3799, 14813], dtype='int64'),
#  30: Int64Index([10434], dtype='int64'),
#  31: Int64Index([8604, 16117, 18674], dtype='int64'),
#  32: Int64Index([7570, 15739], dtype='int64'),
#  33: Int64Index([3800, 14814], dtype='int64'),
#  34: Int64Index([4466], dtype='int64'),
#  35: Int64Index([1589], dtype='int64'),
#  36: Int64Index([10244], dtype='int64'),
#  37: Int64Index([10435, 16978, 19355, 20978], dtype='int64'),
#  38: Int64Index([8605], dtype='int64'),
#  996: Int64Index([10524, 17014, 19387, 20999], dtype='int64'),
#  997: Int64Index([9078], dtype='int64'),
#  998: Int64Index([6159], dtype='int64'),
#  1000: Int64Index([4335, 14942], dtype='int64'),
#  1001: Int64Index([10526, 17016, 19388, 21000], dtype='int64'),
#  1002: Int64Index([9079, 16379, 18874], dtype='int64'),
#  1003: Int64Index([6160], dtype='int64'),
#  1004: Int64Index([4337], dtype='int64'),
#  1005: Int64Index([4930, 15137], dtype='int64'),
#  1006: Int64Index([10527, 17017, 19389, 21001], dtype='int64'),
#  1007: Int64Index([9080], dtype='int64'),
#  1008: Int64Index([7161], dtype='int64'),
#  1009: Int64Index([4338, 14943], dtype='int64'),
#  1010: Int64Index([4932], dtype='int64'),
#  1011: Int64Index([10528], dtype='int64'),
#  1012: Int64Index([7166], dtype='int64'),
#  1013: Int64Index([4934, 15138], dtype='int64'),
#  1014: Int64Index([10529, 17018, 19390, 21002], dtype='int64'),
#  1015: Int64Index([10393], dtype='int64'),
#  1016: Int64Index([1736], dtype='int64'),
#  1017: Int64Index([10394, 16953, 19338], dtype='int64'),
#  1018: Int64Index([4935], dtype='int64'),
#  1019: Int64Index([8390, 16000, 18586], dtype='int64'),
#  1020: Int64Index([5402], dtype='int64'),
#  1021: Int64Index([4936, 15139], dtype='int64'),
#  1022: Int64Index([1739], dtype='int64'),
#  1023: Int64Index([10395], dtype='int64'),
#  1024: Int64Index([8847], dtype='int64'),
#  ...}

# %% [markdown]
# Now, if we want to know the number of performances per program we can simply call `DataFrameGroupBy.size()`

# %%
concerts_grouped_by_ProgramID.size()
# Out:
# ProgramID
# 1        2
# 2        1
# 3        1
# 4        2
# 5        1
# 6        1
# 7        4
# 8        1
# 9        1
# 10       1
# 11       1
# 12       4
# 13       1
# 14       1
# 15       1
# 16       1
# 17       2
# 18       1
# 19       1
# 20       3
# 21       1
# 22       2
# 24       1
# 25       1
# 26       1
# 27       1
# 28       2
# 29       2
# 30       1
# 31       3
#         ..
# 14159    1
# 14160    1
# 14161    1
# 14162    1
# 14163    3
# 14164    1
# 14165    1
# 14166    1
# 14168    2
# 14169    4
# 14170    1
# 14171    1
# 14172    1
# 14173    1
# 14174    1
# 14175    1
# 14176    1
# 14177    3
# 14178    1
# 14179    1
# 14180    1
# 14181    2
# 14182    1
# 14189    2
# 14190    2
# 14191    2
# 14192    1
# 14193    1
# 14194    1
# 14195    1
# Length: 13932, dtype: int64

# %% [markdown]
# The same result but using the all the operations together

# %%
concerts.groupby('ProgramID').size()
# Out:
# ProgramID
# 1        2
# 2        1
# 3        1
# 4        2
# 5        1
# 6        1
# 7        4
# 8        1
# 9        1
# 10       1
# 11       1
# 12       4
# 13       1
# 14       1
# 15       1
# 16       1
# 17       2
# 18       1
# 19       1
# 20       3
# 21       1
# 22       2
# 24       1
# 25       1
# 26       1
# 27       1
# 28       2
# 29       2
# 30       1
# 31       3
#         ..
# 14159    1
# 14160    1
# 14161    1
# 14162    1
# 14163    3
# 14164    1
# 14165    1
# 14166    1
# 14168    2
# 14169    4
# 14170    1
# 14171    1
# 14172    1
# 14173    1
# 14174    1
# 14175    1
# 14176    1
# 14177    3
# 14178    1
# 14179    1
# 14180    1
# 14181    2
# 14182    1
# 14189    2
# 14190    2
# 14191    2
# 14192    1
# 14193    1
# 14194    1
# 14195    1
# Length: 13932, dtype: int64

# %% [markdown]
# With the operation above we obtain a Dataframe with the number of performances per `ProgramID`. If we want to know the most popular ones we need to use the `pd.DataFrame.nlargest()`

# %%
concerts.groupby('ProgramID').size().nlargest()
# Out:
# ProgramID
# 3128     16
# 3139     16
# 10700    16
# 10702    16
# 3134     12
# dtype: int64

# %% [markdown]
# We use `GroupBy.size()` to count the number of elements in each group. A list of available methods:
# * `mean()`
# * `sum()`
# * `size()`
# * `count()`
# * `std()`
# * `var()`
# * `sem()`
# * `describe()`
# * `first()`
# * `last()`
# * `nth()`
# * `min()`
# * `max()`.
#
# Alternatively, we can use `GroupBy.agg()` as a more general method. Check out the [docs](http://pandas.pydata.org/pandas-docs/version/0.22/generated/pandas.core.groupby.DataFrameGroupBy.agg.html).
#
# You could even define your own aggregation function using the lambda nomenclature, we will see an example of it in the transformation topic.

# %% [markdown]
# Let's now imagine that we want to know when it was the first performance of each program.
# We start by `group-by` the shows by `ProgramID` and then, for each group we take the `min` of the Date column.

# %%
concerts.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21607 entries, 0 to 21606
# Data columns (total 8 columns):
# GUID         21607 non-null object
# ProgramID    21607 non-null int64
# ConcertID    21607 non-null int64
# EventType    21590 non-null object
# Location     21588 non-null object
# Venue        21552 non-null object
# Date         21607 non-null object
# Time         20836 non-null object
# dtypes: int64(2), object(6)
# memory usage: 1.3+ MB

# %%
concerts.groupby('ProgramID').Date.min()
# Out:
# ProgramID
# 1        1897-02-05T05:00:00+00:00
# 2        1916-12-03T05:00:00+00:00
# 3        1916-12-06T05:00:00+00:00
# 4        1916-12-07T05:00:00+00:00
# 5        1983-09-14T04:00:00+00:00
# 6        1916-12-09T05:00:00+00:00
# 7        1983-09-15T04:00:00+00:00
# 8        1983-08-06T04:00:00+00:00
# 9        1977-03-05T05:00:00+00:00
# 10       1957-12-01T05:00:00+00:00
# 11       1916-12-10T05:00:00+00:00
# 12       1983-09-22T04:00:00+00:00
# 13       1983-07-27T04:00:00+00:00
# 14       1977-03-14T05:00:00+00:00
# 15       1957-12-03T05:00:00+00:00
# 16       1874-01-17T05:00:00+00:00
# 17       1930-04-03T05:00:00+00:00
# 18       1916-12-11T05:00:00+00:00
# 19       1983-08-05T04:00:00+00:00
# 20       1983-09-29T04:00:00+00:00
# 21       1977-03-23T05:00:00+00:00
# 22       1957-12-05T05:00:00+00:00
# 24       1916-12-13T05:00:00+00:00
# 25       1983-08-02T04:00:00+00:00
# 26       1987-05-02T04:00:00+00:00
# 27       1957-12-08T05:00:00+00:00
# 28       1916-12-14T05:00:00+00:00
# 29       1930-04-05T05:00:00+00:00
# 30       1987-05-05T04:00:00+00:00
# 31       1967-08-01T04:00:00+00:00
#                    ...
# 14159    2017-01-19T05:00:00+00:00
# 14160    2017-01-19T05:00:00+00:00
# 14161    2017-01-20T05:00:00+00:00
# 14170    2015-11-04T05:00:00+00:00
# 14171    2016-04-04T04:00:00+00:00
# 14172    2017-01-18T05:00:00+00:00
# 14173    2017-01-20T05:00:00+00:00
# 14174    2017-03-27T04:00:00+00:00
# 14175    2017-03-30T04:00:00+00:00
# 14176    2017-04-01T04:00:00+00:00
# 14177    2017-02-06T05:00:00+00:00
# 14178    2017-05-02T04:00:00+00:00
# 14179    2017-06-10T04:00:00+00:00
# 14180    2017-06-09T04:00:00+00:00
# 14181    2017-05-23T04:00:00+00:00
# 14182    2017-06-18T04:00:00+00:00
# 14189    2017-06-24T04:00:00+00:00
# 14190    2016-11-10T05:00:00+00:00
# 14191    2016-12-11T05:00:00+00:00
# 14192    2017-01-15T05:00:00+00:00
# 14193    2017-02-03T05:00:00+00:00
# 14194    2017-03-13T04:00:00+00:00
# 14195    2017-04-18T04:00:00+00:00
# Name: Date, Length: 13932, dtype: object

# %% [markdown]
# **Transformation**
#
# The inherent difference between aggregation and transformation is that the later returns an object the same size as the original input.
#
# We don't have an excellent example in our dataset, so let's use the [Iris](https://archive.ics.uci.edu/ml/datasets/iris) dataset to exemplify a possible use case.

# %%
iris = load_iris()
df = pd.DataFrame(data=iris.data, columns=iris.feature_names)
df = df.assign(Target=iris.target)
df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#    Target
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0

# %% [markdown]
# Now, imagine that we want to standardize the data, but using the statistics for each group:
# * We take the mean and the standard deviation *inside each group*
# * We want to standardize each value according to that.
#
# We implement it as a lambda function, that will be applied to each group separately.

# %%
zscore = lambda x: (x - x.mean()) / x.std()

df.groupby('Target').transform(zscore).head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0           0.266674          0.189941          -0.357011         -0.436492
# 1          -0.300718         -1.129096          -0.357011         -0.436492
# 2          -0.868111         -0.601481          -0.932836         -0.436492
# 3          -1.151807         -0.865288           0.218813         -0.436492
# 4          -0.017022          0.453749          -0.357011         -0.436492

# %% [markdown]
# The downside is that, since we are returning the entire dataframe, it can't return `Target` as the index, so we lose the column.
#
# Let's make sure we got this right.

# %%
df_transformed = df.groupby('Target').transform(zscore)

df_transformed.groupby(df['Target']).agg(['mean', 'std'])
# Out:
#        sepal length (cm)      sepal width (cm)      petal length (cm)       \
#                     mean  std             mean  std              mean  std
# Target
# 0           1.845399e-15  1.0    -2.167155e-15  1.0     -1.167955e-15  1.0
# 1           1.143530e-16  1.0    -1.486589e-15  1.0      4.196643e-16  1.0
# 2           2.748912e-15  1.0     7.280287e-16  1.0      6.528111e-16  1.0
#
#        petal width (cm)
#                    mean  std
# Target
# 0          9.281464e-16  1.0
# 1          8.204548e-16  1.0
# 2          6.417089e-16  1.0

# %% [markdown]
# We did it! Zero mean and standard deviation equal to one *inside each group*.
#
# Now, if this use case doesn't ring a bell, think about replacing missing values with the group mean, for example. Useful, right?

# %% [markdown]
# **Filtration**
#
# The method `DataFrameGroupBy.filter()` provides a convenient way to filter out elements that belong to underrepresented groups.

# %%
concerts.groupby('ProgramID').filter(lambda x: x.EventType.str.len()>15)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-104-2a6b535b20ba> in <module>
# ----> 1 concerts.groupby('ProgramID').filter(lambda x: x.EventType.str.len()>15)
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in filter(self, func, dropna, *args, **kwargs)
#    4577                 raise TypeError("filter function returned a %s, "
#    4578                                 "but expected a scalar bool" %
# -> 4579                                 type(res).__name__)
#    4580
#    4581         return self._apply_filter(indices, dropna)
#
# TypeError: filter function returned a Series, but expected a scalar bool

# %%
concerts.groupby('ProgramID').EventType.head()
# Out:
# 0        Subscription Season
# 1        Subscription Season
# 2                    Special
# 3        Subscription Season
# 4        Subscription Season
# 5        Subscription Season
# 6        Subscription Season
# 7        Subscription Season
# 8        Subscription Season
# 9        Subscription Season
# 10       Subscription Season
# 11       Subscription Season
# 12       Subscription Season
# 13       Subscription Season
# 14       Subscription Season
# 15       Subscription Season
# 16                   Special
# 17       Subscription Season
# 18       Subscription Season
# 19       Subscription Season
# 20       Subscription Season
# 21       Subscription Season
# 22       Subscription Season
# 23                   Special
# 24       Subscription Season
# 25       Subscription Season
# 26       Subscription Season
# 27       Subscription Season
# 28       Subscription Season
# 29       Subscription Season
#                 ...
# 21491    Subscription Season
# 21492                  Parks
# 21493    Subscription Season
# 21494    Subscription Season
# 21495    Subscription Season
# 21496                  Parks
# 21497    Subscription Season
# 21498                  Parks
# 21499    Subscription Season
# 21500                  Parks
# 21501    Subscription Season
# 21502    Subscription Season
# 21503                  Parks
# 21504                  Parks
# 21505    Subscription Season
# 21506    Subscription Season
# 21507    Subscription Season
# 21508    Subscription Season
# 21509    Subscription Season
# 21510       Non-Subscription
# 21511    Subscription Season
# 21512    Subscription Season
# 21513               Festival
# 21514       Non-Subscription
# 21515    Subscription Season
# 21516    Subscription Season
# 21517    Subscription Season
# 21518    Subscription Season
# 21519    Subscription Season
# 21520    Subscription Season
# Name: EventType, Length: 21521, dtype: object

# %%
concerts.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21607 entries, 0 to 21606
# Data columns (total 8 columns):
# GUID         21607 non-null object
# ProgramID    21607 non-null int64
# ConcertID    21607 non-null int64
# EventType    21590 non-null object
# Location     21588 non-null object
# Venue        21552 non-null object
# Date         21607 non-null object
# Time         20836 non-null object
# dtypes: int64(2), object(6)
# memory usage: 1.3+ MB

# %%
concerts.groupby('ProgramID').first()
# Out:
#                                                GUID  ConcertID  \
# ProgramID
# 1              471fce4c-58c6-49dc-880f-d133f439760a          0
# 2              6498a041-874c-4fc1-a2d9-efb95dab9f43          0
# 3              dfdabb38-a3a8-4b9d-a5ea-a9c1229b7ec1          0
# 4              c29e6dad-a112-49d5-b167-3e8dee348fa8          0
# 5              6de3d8c8-f3ac-465a-b923-285518329548          0
# 6              3be6f5b7-571c-48d4-acfd-a3718a407258          0
# 7              f040a249-9e58-4d37-9903-b7c51caec4a7          0
# 8              63083927-1ebd-497e-aac1-2a1b62efbcf0          0
# 9              3e0d0533-03ec-4215-8db1-5bdea5f57673          0
# 10             059e1fe7-3d4e-4953-ac8d-5febcf202ffc          0
# 11             64795787-b050-4557-95ff-382b581d80da          0
# 12             eedf0227-ae1f-465f-9edf-e226c2a38d37          0
# 13             606b7df1-13dc-43c5-b288-50f3d2b2df1d          0
# 14             388a1798-ad39-4321-a2be-98ad479f1ac5          0
# 14195          1c3400b1-855d-44d0-9b78-80b65a23c5cd          0
#
#                                      EventType           Location  \
# ProgramID
# 1                          Subscription Season      Manhattan, NY
# 2                          Subscription Season      Manhattan, NY
# 3                          Subscription Season      Manhattan, NY
# 4                          Subscription Season      Manhattan, NY
# 5                          Subscription Season      Manhattan, NY
# 6                          Subscription Season      Manhattan, NY
# 7                          Subscription Season      Manhattan, NY
# 8                                         Tour      St. Louis, MO
# 9                       Young People's Concert      Manhattan, NY
# 10                         Subscription Season      Manhattan, NY
# 11                         Subscription Season       Brooklyn, NY
# 12                         Subscription Season      Manhattan, NY
# 13                                        Tour      Hollywood, CA
# 14                             Student Concert      Manhattan, NY
# 15                                      Runout       Hartford, CT
# 16                         Subscription Season      Manhattan, NY
# 17                         Subscription Season      Manhattan, NY
# 18                                      Runout       Newburgh, NY
# 19                                        Tour          Tulsa, OK
# 20                         Subscription Season      Manhattan, NY
# 21                             Student Concert      Manhattan, NY
# 22                         Subscription Season      Manhattan, NY
# 24                         Subscription Season      Manhattan, NY
# 25                                        Tour          Tempe, AZ
# 26                Pension Fund Benefit Concert      Manhattan, NY
# 27                         Subscription Season      Manhattan, NY
# 28                         Subscription Season      Manhattan, NY
# 29                             Student Concert      Manhattan, NY
# 30                         Subscription Season      Manhattan, NY
# 31                                       Parks      Manhattan, NY
# ...                                        ...                ...
# 14159      Young People's Concerts for Schools      Manhattan, NY
# 14160      Young People's Concerts for Schools      Manhattan, NY
# 14161      Young People's Concerts for Schools      Manhattan, NY
# 14162      Young People's Concerts for Schools      Manhattan, NY
# 14163              Very Young People's Concert      Manhattan, NY
# 14164                Chamber Concert (Private)      Manhattan, NY
# 14165                             Off the Grid       Brooklyn, NY
# 14166                                  Chamber      Manhattan, NY
# 14168                      Subscription Season      Manhattan, NY
# 14169                                    Parks          Bronx, NY
# 14170                                  Chamber      Manhattan, NY
# 14171                                  Chamber      Manhattan, NY
# 14172                Chamber Concert (Private)      Manhattan, NY
# 14173                                Residency    Interlochen, MI
# 14174               Tour - Concert for Patrons  Budapest, HUNGARY
# 14175               Tour - Concert for Patrons    Vienna, AUSTRIA
# 14176         Tour Very Young People's Concert    London, ENGLAND
# 14177              Very Young People's Concert      Manhattan, NY
# 14178                             Off the Grid       Brooklyn, NY
# 14179                      Subscription Season      Manhattan, NY
# 14180                      Subscription Season      Manhattan, NY
# 14181                      Subscription Season      Manhattan, NY
# 14182              Parks - Free Indoor Concert  Staten Island, NY
# 14189                                  Chamber   East Hampton, NY
# 14190                Chamber Concert (Private)      Manhattan, NY
# 14191                                      NaN      Manhattan, NY
# 14192                                  Chamber      Manhattan, NY
# 14193                                 Festival      Manhattan, NY
# 14194                Chamber Concert (Private)      Manhattan, NY
# 14195                Chamber Concert (Private)      Manhattan, NY
#
#                                                        Venue  \
# ProgramID
# 1                                              Carnegie Hall
# 2                                              Carnegie Hall
# 3                                              Carnegie Hall
# 4                                              Carnegie Hall
# 5                                          Avery Fisher Hall
# 6                                              Carnegie Hall
# 7                                          Avery Fisher Hall
# 8                                                Fox Theatre
# 9                                          Avery Fisher Hall
# 10                                             Carnegie Hall
# 11                                 Brooklyn Academy of Music
# 12                                         Avery Fisher Hall
# 13                                            Hollywood Bowl
# 14                                         Avery Fisher Hall
# 15                                       Bushnell Auditorium
# 16                                          Academy of Music
# 17                                             Carnegie Hall
# 18                                          Academy of Music
# 19                            Performing Arts Center (Tulsa)
# 20                                         Avery Fisher Hall
# 21                                         Avery Fisher Hall
# 22                                             Carnegie Hall
# 24                                             Carnegie Hall
# 25                    Gammage Center for the Performing Arts
# 26                                         Avery Fisher Hall
# 27                                             Carnegie Hall
# 28                                             Carnegie Hall
# 29                                             Carnegie Hall
# 30                                         Avery Fisher Hall
# 31                                              Sheep Meadow
# ...                                                      ...
# 14159                                      David Geffen Hall
# 14160                                      David Geffen Hall
# 14161                                      David Geffen Hall
# 14162                                      David Geffen Hall
# 14163                                    Merkin Concert Hall
# 14164                                        University Club
# 14165                                        Bell House, The
# 14166        Theresa L. Kaufmann Concert Hall, 92nd St. YMHA
# 14168                                      David Geffen Hall
# 14169                                     Van Cortlandt Park
# 14170                                        Three West Club
# 14171                        The Stanley H. Kaplan Penthouse
# 14172             Home of Neil Westreich and Michael O'Keefe
# 14173                                Interlochen Arts Center
# 14174      Vadászterem [Hunters Hall] in the Hungarian Pa...
# 14175             Johann Strauss Concert Hall, Palais Coburg
# 14176            Milton Court at Guild Hall, Barbican Centre
# 14177                                    Merkin Concert Hall
# 14178                                           House of Yes
# 14179                                      David Geffen Hall
# 14180                                      David Geffen Hall
# 14181                                      David Geffen Hall
# 14182                                            Snug Harbor
# 14189                                             Guild Hall
# 14190                                      Cosmopolitan Club
# 14191                                      David Geffen Hall
# 14192                                Bruno Walter Auditorium
# 14193                                   St. Paul the Apostle
# 14194                        Weill Music Room, Carnegie Hall
# 14195                        The Stanley H. Kaplan Penthouse
#
#                                 Date     Time
# ProgramID
# 1          1897-02-05T05:00:00+00:00   2:00PM
# 2          1916-12-03T05:00:00+00:00   3:00PM
# 3          1916-12-06T05:00:00+00:00      NaN
# 4          1916-12-07T05:00:00+00:00   8:30PM
# 5          1983-09-14T04:00:00+00:00   8:00PM
# 6          1916-12-09T05:00:00+00:00   8:30PM
# 7          1983-09-15T04:00:00+00:00   8:00PM
# 8          1983-08-06T04:00:00+00:00   3:00PM
# 9          1977-03-05T05:00:00+00:00   2:00PM
# 10         1957-12-01T05:00:00+00:00   3:00PM
# 11         1916-12-10T05:00:00+00:00   3:15PM
# 12         1983-09-22T04:00:00+00:00   8:00PM
# 13         1983-07-27T04:00:00+00:00   8:30PM
# 14         1977-03-14T05:00:00+00:00   1:30PM
# 15         1957-12-03T05:00:00+00:00      NaN
# 16         1874-01-17T05:00:00+00:00   8:00PM
# 17         1930-04-03T05:00:00+00:00   8:45PM
# 18         1916-12-11T05:00:00+00:00   8:00PM
# 19         1983-08-05T04:00:00+00:00   8:00PM
# 20         1983-09-29T04:00:00+00:00   8:00PM
# 21         1977-03-23T05:00:00+00:00  10:30AM
# 22         1957-12-05T05:00:00+00:00   8:45PM
# 24         1916-12-13T05:00:00+00:00   8:15PM
# 25         1983-08-02T04:00:00+00:00   8:00PM
# 26         1987-05-02T04:00:00+00:00   8:00PM
# 27         1957-12-08T05:00:00+00:00   3:00PM
# 28         1916-12-14T05:00:00+00:00   8:30PM
# 29         1930-04-05T05:00:00+00:00   8:45PM
# 30         1987-05-05T04:00:00+00:00   8:30PM
# 31         1967-08-01T04:00:00+00:00   8:30PM
# ...                              ...      ...
# 14159      2017-01-19T05:00:00+00:00  10:30AM
# 14160      2017-01-19T05:00:00+00:00  12:00PM
# 14161      2017-01-20T05:00:00+00:00  11:00AM
# 14162      2017-01-20T05:00:00+00:00  12:30PM
# 14163      2017-01-09T05:00:00+00:00  10:30PM
# 14164      2015-01-21T05:00:00+00:00   7:30PM
# 14165      2017-01-19T05:00:00+00:00   8:00PM
# 14166      2017-01-29T05:00:00+00:00   1:50PM
# 14168      2017-02-09T05:00:00+00:00   7:30PM
# 14169      2017-06-13T04:00:00+00:00   8:00PM
# 14170      2015-11-04T05:00:00+00:00   3:00PM
# 14171      2016-04-04T04:00:00+00:00      NaN
# 14172      2017-01-18T05:00:00+00:00      NaN
# 14173      2017-01-20T05:00:00+00:00   7:30PM
# 14174      2017-03-27T04:00:00+00:00   6:45PM
# 14175      2017-03-30T04:00:00+00:00   6:30PM
# 14176      2017-04-01T04:00:00+00:00   2:30PM
# 14177      2017-02-05T05:00:00+00:00  12:30PM
# 14178      2017-05-02T04:00:00+00:00   8:00PM
# 14179      2017-06-10T04:00:00+00:00   8:00PM
# 14180      2017-06-09T04:00:00+00:00   8:00PM
# 14181      2017-05-20T04:00:00+00:00   8:00PM
# 14182      2017-06-18T04:00:00+00:00   3:00PM
# 14189      2017-06-24T04:00:00+00:00      NaN
# 14190      2016-11-10T05:00:00+00:00   3:00PM
# 14191      2016-12-11T05:00:00+00:00   3:00PM
# 14192      2017-01-15T05:00:00+00:00   3:00PM
# 14193      2017-02-03T05:00:00+00:00   7:30PM
# 14194      2017-03-13T04:00:00+00:00   8:45PM
# 14195      2017-04-18T04:00:00+00:00   7:00PM
#
# [13932 rows x 7 columns]

# %%
concerts.EventType.unique()
# Out:
# array(['Subscription Season', 'Special', 'Chamber', 'Tour',
#        "Young People's Concert", 'Non-Subscription',
#        'Pension Fund Benefit Concert', 'Runout', 'Private Concert',
#        'Stadium Concert', 'Student Concert', nan,
#        "Young People's Concerts for Schools", 'Chamber Concert (Private)',
#        'Festival', "World's Fair", 'Summer Broadcast Concert',
#        'Carnegie Pop Concert', 'Pre-Concert Recital', 'Promenade',
#        'Parks', 'Prospective Encounters', 'Informal Evening',
#        'Rug Concerts', 'Strike Concerts', 'Tour - Chamber', 'Horizons',
#        'Festival - Chamber', 'Rush Hour', 'Saturday Matinee',
#        'St. John the Divine', 'Holiday Brass', 'Master Class',
#        'Leinsdorf Lecture', 'Recording Session Only',
#        "Tour - Young People's Concerts for Schools",
#        'World Trade Center - Chamber', 'Borough Concerts',
#        'Tour - Concert for Patrons', 'Summertime Classics', 'Lecture',
#        "Very Young People's Concert", 'Inside the Music', 'Hear & Now',
#        'Insight Series', "Tour - Young People's Concert",
#        'Parks - Free Indoor Concert', 'Contact!', "New Year's Eve",
#        'Soloist Recital', 'NY Phil Biennial', 'Reading Rehearsal',
#        'Residency - Chamber', 'Residency', 'Off the Grid',
#        'Artist in Residence recital', "Tour Very Young People's Concert",
#        'Sponsor Chamber Music'], dtype=object)

# %%
concerts.groupby('ProgramID').filter(lambda x: x.shape[0] > 15).sort_values(by='ProgramID')
# Out:
#                                        GUID  ProgramID  ConcertID EventType  \
# 6608   8ad0bfa4-09b9-4b18-889b-d0c426410cbb       3128          0   Special
# 21523  8ad0bfa4-09b9-4b18-889b-d0c426410cbb       3128          5   Special
# 21549  8ad0bfa4-09b9-4b18-889b-d0c426410cbb       3128          7   Special
# 21430  8ad0bfa4-09b9-4b18-889b-d0c426410cbb       3128          4   Special
# 21559  8ad0bfa4-09b9-4b18-889b-d0c426410cbb       3128          8   Special
# 21567  8ad0bfa4-09b9-4b18-889b-d0c426410cbb       3128          9   Special
# 20323  8ad0bfa4-09b9-4b18-889b-d0c426410cbb       3128          3   Special
# 21537  8ad0bfa4-09b9-4b18-889b-d0c426410cbb       3128          6   Special
# 21575  8ad0bfa4-09b9-4b18-889b-d0c426410cbb       3128         10   Special
# 21599  8ad0bfa4-09b9-4b18-889b-d0c426410cbb       3128         14   Special
# 21603  8ad0bfa4-09b9-4b18-889b-d0c426410cbb       3128         15   Special
# 21595  8ad0bfa4-09b9-4b18-889b-d0c426410cbb       3128         13   Special
# 15517  8ad0bfa4-09b9-4b18-889b-d0c426410cbb       3128          1   Special
# 21583  8ad0bfa4-09b9-4b18-889b-d0c426410cbb       3128         11   Special
# 21591  8ad0bfa4-09b9-4b18-889b-d0c426410cbb       3128         12   Special
# 18344  8ad0bfa4-09b9-4b18-889b-d0c426410cbb       3128          2   Special
# 21596  1e1114aa-7152-4305-a357-7aac149b8599       3139         13   Special
# 21577  1e1114aa-7152-4305-a357-7aac149b8599       3139         10   Special
# 21561  1e1114aa-7152-4305-a357-7aac149b8599       3139          8   Special
# 21551  1e1114aa-7152-4305-a357-7aac149b8599       3139          7   Special
# 21585  1e1114aa-7152-4305-a357-7aac149b8599       3139         11   Special
# 21592  1e1114aa-7152-4305-a357-7aac149b8599       3139         12   Special
# 21569  1e1114aa-7152-4305-a357-7aac149b8599       3139          9   Special
# 21539  1e1114aa-7152-4305-a357-7aac149b8599       3139          6   Special
# 21525  1e1114aa-7152-4305-a357-7aac149b8599       3139          5   Special
# 21600  1e1114aa-7152-4305-a357-7aac149b8599       3139         14   Special
# 6610   1e1114aa-7152-4305-a357-7aac149b8599       3139          0   Special
# 21432  1e1114aa-7152-4305-a357-7aac149b8599       3139          4   Special
# 21604  1e1114aa-7152-4305-a357-7aac149b8599       3139         15   Special
# 15519  1e1114aa-7152-4305-a357-7aac149b8599       3139          1   Special
# ...                                     ...        ...        ...       ...
# 21579  b37d1833-3252-41a6-9f3e-fbd596b215b0      10700         10   Special
# 21598  Manhattan, NY  Roxy Theatre  1951-05-19T04:00:00+00:00      NaN
# 21594  Manhattan, NY  Roxy Theatre  1951-05-19T04:00:00+00:00      NaN
# 21602  Manhattan, NY  Roxy Theatre  1951-05-19T04:00:00+00:00      NaN
# 21555  Manhattan, NY  Roxy Theatre  1951-05-17T04:00:00+00:00  12:40PM
# 21581  Manhattan, NY  Roxy Theatre  1951-05-18T04:00:00+00:00      NaN
# 21573  Manhattan, NY  Roxy Theatre  1951-05-18T04:00:00+00:00      NaN
# 21565  Manhattan, NY  Roxy Theatre  1951-05-18T04:00:00+00:00      NaN
# 21543  Manhattan, NY  Roxy Theatre  1951-05-17T04:00:00+00:00      NaN
# 21529  Manhattan, NY  Roxy Theatre  1951-05-17T04:00:00+00:00      NaN
# 21436  Manhattan, NY  Roxy Theatre  1951-05-17T04:00:00+00:00      NaN
# 20331  Manhattan, NY  Roxy Theatre  1951-05-16T04:00:00+00:00  12:40PM
# 18357  Manhattan, NY  Roxy Theatre  1951-05-16T04:00:00+00:00      NaN
# 15555  Manhattan, NY  Roxy Theatre  1951-05-16T04:00:00+00:00      NaN
# 6691   Manhattan, NY  Roxy Theatre  1951-05-16T04:00:00+00:00      NaN
# 21589  Manhattan, NY  Roxy Theatre  1951-05-18T04:00:00+00:00  12:40PM
# 21606  Manhattan, NY  Roxy Theatre  1951-05-19T04:00:00+00:00  12:40PM
#
# [64 rows x 8 columns]

# %% [markdown]
# It returns a subset of the original dataframe, depending on a function applied to the group as a whole.

# %% [markdown]
# ### 1.2.4 Method chaining
#
# Now we know about some of the most common individual transformations we can use. But how can we combine them?
#
# Data transformation is a pipeline, i.e., some sequential transformations, *chained* together.
#
# This chaining means that each transformation returns an object that will be consumed by the next one, and so on, in a pre-defined order.
#
# As we've seen, a familiar syntax is to declare intermediate variables for each output, used as input to the next function.

# %% [markdown]
# As an example, let us define a simple function that make the subset of a dataframe based on a mask

# %%
def subset(df, mask):
    return df[mask]

# %%
mask = works['Interval'].isnull()
df_no_intervals = subset(works,mask)

df_exclude_minor_composers = df_no_intervals.groupby('ComposerName').filter(lambda x: x.shape[0] > 10)

df_work_related = df_exclude_minor_composers.filter(items=work_related_columns)
df_work_related_no_movement = df_work_related.drop(columns='Movement')
df_work_related_no_movement_unique = df_work_related_no_movement.drop_duplicates()

works_per_composer = df_work_related_no_movement_unique.groupby('ComposerName').size()
works_per_composer_sorted = works_per_composer.nlargest()
works_per_composer_sorted
# Out:
# ComposerName
# Traditional,                  640
# Bach,  Johann  Sebastian      306
# Mozart,  Wolfgang  Amadeus    242
# Schubert,  Franz              158
# Beethoven,  Ludwig  van       144
# dtype: int64

# %% [markdown]
# These declarations are syntactic sugar: they make it easier to read and express confusing things such as data pipelines. Some downsides:
# * We need to create an extra variable per intermediate step
# * Cognitive burden of naming each variable and keeping them in mind
# * They make the code less fluid
# * They make it harder to visualize the whole picture of what your program (or Notebook) is doing
# * They are error-prone and heavily reliant on the state, which is dangerous as we've seen.
#
# What if there was an alternative?
#
# Method chaining allows invoking multiple method calls chained together in a single statement, each receiving and returning an object.
#
# This syntax has always been possible with Pandas, but more and more methods and being added that (try to guess it!):
# * Receive a dataframe
# * Return a transformed dataframe.

# %%
no_intervals = works['Interval'].isnull()
df_no_intervals = subset(works,mask)

df_work_related = df_no_intervals.filter(items=work_related_columns)

(df_work_related.groupby('ComposerName').filter(lambda x: x.shape[0] > 10)
                .drop(columns='Movement')
                .drop_duplicates()
                .groupby('ComposerName').size()
                .nlargest()
                .plot(kind='bar'));

# %% [markdown]
# Code flows from top to bottom, and the function parameters are always near the function.
#
# Also, you eliminate an extra variable for each intermediate steps.
#
# Now, explicitly naming things is good. Ideally, you want to chain functions that make sense together and encapsulate them in logically.

# %%
def get_top_5_composers(df):
    df = df.copy()
    
    no_intervals = df['Interval'].isnull()
    df = subset(df, no_intervals)
    
    work_related_columns = ['ComposerName', 'WorkTitle', 'Movement']
    
    df = (df.filter(work_related_columns)
            .groupby('ComposerName').filter(lambda x: x.shape[0] > 10)
            .drop(columns='Movement')
            .drop_duplicates()
            .groupby('ComposerName').size()
            .nlargest())
    return df

top_5_composers = get_top_5_composers(works)
top_5_composers
# Out:
# ComposerName
# Traditional,                  640
# Bach,  Johann  Sebastian      306
# Mozart,  Wolfgang  Amadeus    242
# Schubert,  Franz              158
# Beethoven,  Ludwig  van       144
# dtype: int64

# %% [markdown]
# Another drawback to excessively long chains is that debugging is harder, as there no intermediate values to inspect.
#
# **Segregate your code as to avoid long chains and keep only together what belongs together.**
#
# (In case of doubt, read [The Zen of Python](https://www.python.org/dev/peps/pep-0020/) out loud ten times.)
#
# ### 1.2.5 Custom methods and pipes
#
# Now, for the final trick.
#
# The function `subset()` has the exact signature we want, again:
# * It receives a dataframe
# * It return a transformed dataframe.
#
# What if Pandas had a way to include such functions in pipelines? Meet `df.pipe()`!
#
# The method `df.pipe()` allows us to include user-defined functions in method chains (aka pipelines).
#
# It works like this.

# %%
(df_work_related.pipe(subset, no_intervals)
                .filter(items=work_related_columns)
                .groupby('ComposerName').filter(lambda x: x.shape[0] > 10)
                .drop(columns='Movement')
                .drop_duplicates()
                .groupby('ComposerName').size()
                .nlargest()
                .plot(kind='bar'));
# Out:
# C:\Users\jnpicao\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.

# %% [markdown]
# So, this should work.

# %%
def get_top_5_composers(df):
    no_intervals = df['Interval'].isnull()
    work_related_columns = ['ComposerName', 'WorkTitle', 'Movement']
    
    df = df.copy()
    df = (df.pipe(subset, no_intervals)
            .filter(items=work_related_columns)
            .groupby('ComposerName').filter(lambda x: x.shape[0] > 10)
            .drop(columns='Movement')
            .drop_duplicates()
            .groupby('ComposerName').size()
            .nlargest())
    
    return df

top_5_composers = get_top_5_composers(works)
top_5_composers
# Out:
# ComposerName
# Traditional,                  640
# Bach,  Johann  Sebastian      306
# Mozart,  Wolfgang  Amadeus    242
# Schubert,  Franz              158
# Beethoven,  Ludwig  van       144
# dtype: int64

# %% [markdown]
# And it does!
#
# Now, we have all the tools we need to build robust data transformation pipelines in Pandas.
#
# In the next Notebook, you will learn how to combine dataframes.
