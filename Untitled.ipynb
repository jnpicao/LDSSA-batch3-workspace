# %%
# Operating System
import os

import pandas as pd
import numpy as np

# Strings
import re

# %%
def create_conversion_lower_case_dict():
    
    conversion_lists = []
    
    # Conversion for character a
    conversion_lists.append(['a'] + [chr(c) for c in range(224,231)])
    
    # Conversion for character e
    conversion_lists.append(['e'] + [chr(c) for c in range(232,236)])
    
    # Conversion for character i
    conversion_lists.append(['i'] + [chr(c) for c in range(236,240)])
    
    # Conversion for character o
    conversion_lists.append(['o'] + [chr(c) for c in range(242,247)])
    
    # Conversion for character u
    conversion_lists.append(['u'] + [chr(c) for c in range(249,253)])
    
    # Conversion for character c
    conversion_lists.append(['c'] + [chr(231)])
    
    # Conversion for character n
    conversion_lists.append(['n'] + [chr(241)])
    
    
    conversion_dict = {}
    for single_letter_list in conversion_lists:
        
        single_letter_dict = str.maketrans(''.join(single_letter_list[1:]), single_letter_list[0]*len(single_letter_list[1:]))
        conversion_dict.update(single_letter_dict)
        
    return conversion_dict

# %%
def hospital_name_clean(string_series, conversion_dict=None):
    
    new_series = string_series.copy()
    
    # Make sure it is a string!
    new_series = new_series.astype(str)
    
    # lowercase
    new_series = new_series.str.lower()
    
    
    # Retira os acentos e cedilhas
    if conversion_dict != None:
        new_series = new_series.str.translate(conversion_dict)
        
    # remove or replace special characters
    new_series = new_series.str.replace(r'[^a-zA-Z0-9]', r' ',regex=True)
    
    
    # remover expressões mais frequentes
    remove_list = [r'\sde\s', 
                   r'\sdo\s', 
                   r'\sda\s', 
                   r'\se\s', 
                   r'hospital\s', 
                   r'h\s', 
                   r'ch\s', 
                   r'centro hospitalar\s', 
                   r'epe$', 
                   r'ppp$']
    for word in remove_list:
        new_series = new_series.str.replace(word, ' ',regex=True)
    
    
    # remove or replace special characters
    new_series = new_series.str.replace(r' +', r' ',regex=True)
        
    # Trim
    new_series = new_series.str.strip()
    
    return new_series

# %% [markdown]
# ### df1: Doentes Saidos por cama/mês

# %%
file_path = os.path.join('data', '1.8.Doentes Saidos por cama_mês.xlsx')

df1 = pd.read_excel(file_path)

# %%
df1['indicador'] = "Número de doentes saídos por cama/mês"

# %%
df1['sub-indicador'] = ""

# %%
df1['Ficheiro'] = "1.8.Doentes Saidos por cama_mês.xlsx"

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3747 entries, 0 to 3746
# Data columns (total 7 columns):
# Instituição      3747 non-null object
# Ano              3747 non-null int64
# Mês              3747 non-null int64
# Valor            3667 non-null float64
# indicador        3747 non-null object
# sub-indicador    3747 non-null object
# Ficheiro         3747 non-null object
# dtypes: float64(1), int64(2), object(4)
# memory usage: 205.0+ KB

# %%
df1.columns = ['Hospital', 'Ano', 'Mes', 'Valor', 'Indicador', 'Sub-indicador', 'Ficheiro']

# %%
df1 = df1[['Hospital', 'Ano', 'Mes', 'Indicador', 'Sub-indicador', 'Valor', 'Ficheiro']]

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3747 entries, 0 to 3746
# Data columns (total 7 columns):
# Hospital         3747 non-null object
# Ano              3747 non-null int64
# Mes              3747 non-null int64
# Indicador        3747 non-null object
# Sub-indicador    3747 non-null object
# Valor            3667 non-null float64
# Ficheiro         3747 non-null object
# dtypes: float64(1), int64(2), object(4)
# memory usage: 205.0+ KB

# %% [markdown]
# ### df2:

# %%
dir_path = os.path.join('data', '1.13_1.15_1.16_5.2_5.4.1_HOSP')

df2 = pd.DataFrame({'Hospital': [], 'Ano':[] , 'Mes':[] , 'Indicador':[] , 'Sub-indicador':[] , 'Valor':[], 'Ficheiro':[]})
df_aux = None
file_counter = 0

cols_to_keep = [3, 10, 14, 30, 32, 60, 62, 64]

for filename in os.listdir(dir_path):
    
    ano = filename[:4]
    mes = filename[5:7]
    
    df_aux = pd.read_excel(os.path.join(dir_path, filename))
    df_aux = df_aux.iloc[:,cols_to_keep]
    
    df_aux['Ano'] = ano
    df_aux['Mes'] = mes
    
    df_aux = df_aux.set_index(['Hospital', 'Ano', 'Mes'])
    df_aux.columns = (['Mediana do tempo de espera da LIC',
                       'Percentagem de utentes em LIC dentro do TMRG',
                       'Média do tempo de espera dos operados',
                       'Percentagem de doentes operados dentro dos TMRG',
                       'Taxa de disponibilidade do bloco operatório',
                       'Número de cirurgias por especialista de cirurgia',
                       'Número de cirurgias por anestesiologista'])
    
    df_aux = df_aux.stack().to_frame()
    df_aux.columns = ['Valor']
    
    df_aux.index.set_names('Indicador', level=3, inplace=True)
    
    df_aux = df_aux.reset_index()
    
    df_aux['Sub-indicador'] = ""
    
    df_aux['Ficheiro'] = filename
    
    
    
    df_aux = df_aux[['Hospital', 'Ano', 'Mes', 'Indicador', 'Sub-indicador', 'Valor', 'Ficheiro']]
    
    df2 = df2.append(df_aux)
    
    #df_aux= None
    file_counter += 1
    

df2 = df2.reset_index(drop=True)

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23546 entries, 0 to 23545
# Data columns (total 7 columns):
# Hospital         22982 non-null object
# Ano              23546 non-null object
# Mes              23546 non-null object
# Indicador        23546 non-null object
# Sub-indicador    23546 non-null object
# Valor            23546 non-null object
# Ficheiro         23546 non-null object
# dtypes: object(7)
# memory usage: 1.3+ MB

# %%
df2.sample(20)
# Out:
#                                       Hospital   Ano Mes  \
# 11316                  PPFMNS - H. Santa Maria  2017  11
# 7832          ULS Litoral Alent. - Sant. Cacém  2017  04
# 6386                            CH Baixo Vouga  2017  02
# 16404                    Sª Cª M. de Benavente  2018  09
# 19449  Sª Cª M. R. d'Ave - H. Narciso Ferreira  2019  03
# 14845           Inst. Oft. Dr. Gama Pinto - Lx  2018  06
# 21261                            H D. Santarém  2019  07
# 10290                               IPO Lisboa  2017  09
# 13557                       CH Tondela - Viseu  2018  04
# 8515                     CH Univer. do Algarve  2017  06
# 15335                              HPA - Alvor  2018  07
# 20050                           CH Baixo Vouga  2019  05
# 15604                 CH Univer. Cova da Beira  2018  08
# 17532                                      NaN  2018  11
# 17348            H Sra da Oliveira - Guimarães  2018  11
# 3654                H Dr. Franc. Zagalo - Ovar  2016  08
# 19740               H Cruz Vermelha Portuguesa  2019  04
# 18311                           H Luz - Aveiro  2019  01
# 11522                       CH Tondela - Viseu  2017  12
# 21377                        HOSPOR - Clipóvoa  2019  07
#
#                                               Indicador Sub-indicador  \
# 11316   Percentagem de doentes operados dentro dos TMRG
# 7832                  Mediana do tempo de espera da LIC
# 6386                  Mediana do tempo de espera da LIC
# 16404             Média do tempo de espera dos operados
# 19449                 Mediana do tempo de espera da LIC
# 14845   Percentagem de doentes operados dentro dos TMRG
# 21261          Número de cirurgias por anestesiologista
# 10290  Número de cirurgias por especialista de cirurgia
# 13557          Número de cirurgias por anestesiologista
# 8515              Média do tempo de espera dos operados
# 15335             Média do tempo de espera dos operados
# 20050          Número de cirurgias por anestesiologista
# 15604      Percentagem de utentes em LIC dentro do TMRG
# 17532  Número de cirurgias por especialista de cirurgia
# 17348       Taxa de disponibilidade do bloco operatório
# 3654        Taxa de disponibilidade do bloco operatório
# 19740             Média do tempo de espera dos operados
# 18311             Média do tempo de espera dos operados
# 11522   Percentagem de doentes operados dentro dos TMRG
# 21377             Média do tempo de espera dos operados
#
#           Valor           Ficheiro
# 11316  0.115578  2017_11_HOSP.xlsx
# 7832    3.16667  2017_04_HOSP.xlsx
# 6386        2.9  2017_02_HOSP.xlsx
# 16404   1.46521  2018_09_HOSP.xlsx
# 19449  0.666667  2019_03_HOSP.xlsx
# 14845  0.104825  2018_06_HOSP.xlsx
# 21261   97.4539  2019_07_HOSP.xlsx
# 10290    48.485  2017_09_HOSP.xlsx
# 13557    87.113  2018_04_HOSP.xlsx
# 8515    3.44036  2017_06_HOSP.xlsx
# 15335  0.971974  2018_07_HOSP.xlsx
# 20050   69.3399  2019_05_HOSP.xlsx
# 15604  0.337306  2018_08_HOSP.xlsx
# 17532    < 53,3  2018_11_HOSP.xlsx
# 17348  0.983333  2018_11_HOSP.xlsx
# 3654        1.4  2016_08_HOSP.xlsx
# 19740   2.09139  2019_04_HOSP.xlsx
# 18311  0.929739  2019_01_HOSP.xlsx
# 11522  0.373185  2017_12_HOSP.xlsx
# 21377  0.253182  2019_07_HOSP.xlsx

# %% [markdown]
# ### df3

# %%
file_path = os.path.join('data', '1.2.Tempo de internamento padronizado, por especialidade;.xlsx')

df3 = pd.read_excel(file_path)

df3.index = df3.index.droplevel(0)
#df3.index = df3.index.droplevel(0)

df3 = df3.stack().to_frame()

df3.columns = ['Valor']

df3.index.set_names('Indicador', level=0, inplace=True)

df3 = df3.reset_index()

df3.columns = ['Indicador','data','Hospital','Valor']

df3['Ano'] = df3.data.dt.year
df3['Mes'] = df3.data.dt.month
df3['Sub-indicador'] = ""
df3['Indicador'] = "Índice de demora média ajustada"
df3['Ficheiro'] = "1.2.Tempo de internamento padronizado, por especialidade;.xlsx"


df3 = df3[['Hospital', 'Ano', 'Mes', 'Indicador', 'Sub-indicador', 'Valor', 'Ficheiro']]

# %%
df3.head(10)
# Out:
#                                             Hospital   Ano  Mes  \
# 0              Hospital Espírito Santo de Évora, EPE  2016    1
# 1      Unidade Local de Saúde do Baixo Alentejo, EPE  2016    1
# 2  Unidade Local de Saúde do Litoral Alentejano, EPE  2016    1
# 3    Unidade Local de Saúde do Norte Alentejano, EPE  2016    1
# 4    Centro Hospitalar Universitário do Algarve, EPE  2016    1
# 5                   Centro Hospitalar de Leiria, EPE  2016    1
# 6              Centro Hospitalar do Baixo Vouga, EPE  2016    1
# 7  Centro Hospitalar e Universitário de Coimbra, EPE  2016    1
# 8               Centro Hospitalar Tondela-Viseu, EPE  2016    1
# 9  Centro Hospitalar Universitário Cova da Beira,...  2016    1
#
#                          Indicador Sub-indicador     Valor  \
# 0  Índice de demora média ajustada                0.971876
# 1  Índice de demora média ajustada                0.991868
# 2  Índice de demora média ajustada                0.967448
# 3  Índice de demora média ajustada                0.928805
# 4  Índice de demora média ajustada                0.905354
# 5  Índice de demora média ajustada                0.807901
# 6  Índice de demora média ajustada                0.936693
# 7  Índice de demora média ajustada                0.939853
# 8  Índice de demora média ajustada                0.879996
# 9  Índice de demora média ajustada                1.156804
#
#                                             Ficheiro
# 0  1.2.Tempo de internamento padronizado, por esp...
# 1  1.2.Tempo de internamento padronizado, por esp...
# 2  1.2.Tempo de internamento padronizado, por esp...
# 3  1.2.Tempo de internamento padronizado, por esp...
# 4  1.2.Tempo de internamento padronizado, por esp...
# 5  1.2.Tempo de internamento padronizado, por esp...
# 6  1.2.Tempo de internamento padronizado, por esp...
# 7  1.2.Tempo de internamento padronizado, por esp...
# 8  1.2.Tempo de internamento padronizado, por esp...
# 9  1.2.Tempo de internamento padronizado, por esp...

# %% [markdown]
# ### df4

# %%
dir_path = os.path.join('data', '5.3.1_CTH_lista pedidos de consulta')

df4 = pd.DataFrame({'Hospital': [], 'Ano':[] , 'Mes':[] , 'Indicador':[] , 'Sub-indicador':[] , 'Valor':[], 'Ficheiro':[]})
df_aux = None
file_counter = 0

cols_to_keep = [1, 4]

for filename in os.listdir(dir_path):
    
    ano = filename[-13:-9]
    mes = filename[-16:-14]
    
    df_aux = pd.read_excel(os.path.join(dir_path, filename), sheet_name=0)
    df_aux = df_aux.iloc[:,cols_to_keep]
    
    df_aux['Ano'] = ano
    df_aux['Mes'] = mes
    
    df_aux = df_aux.rename(columns={'Instituição':'Hospital', 'Mediana do TE (pedidos não concluídos) (dias)': 'Valor'})
    
    df_aux['Indicador'] = "Mediana do tempo de espera da LEC"
    
    df_aux['Sub-indicador'] = ""
    
    df_aux['Ficheiro'] = filename  
    
    df_aux = df_aux[['Hospital', 'Ano', 'Mes', 'Indicador', 'Sub-indicador', 'Valor', 'Ficheiro']]
    
    df4 = df4.append(df_aux)
    
    #df_aux= None
    file_counter += 1
    

df4 = df4.reset_index(drop=True)

# %%
df4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1200 entries, 0 to 1199
# Data columns (total 7 columns):
# Hospital         1200 non-null object
# Ano              1200 non-null object
# Mes              1200 non-null object
# Indicador        1200 non-null object
# Sub-indicador    1200 non-null object
# Valor            1200 non-null float64
# Ficheiro         1200 non-null object
# dtypes: float64(1), object(6)
# memory usage: 65.7+ KB

# %%
df4.head()
# Out:
#                                             Hospital   Ano Mes  \
# 0               HOSPITAL DR. FRANCISCO ZAGALO - OVAR  2018  01
# 1    HOSPITAL ARCEBISPO JOÃO CRISÓSTOMO - CANTANHEDE  2018  01
# 2  CENTRO MÉDICO DE REABILITAÇÃO DA REGIÃO CENTRO...  2018  01
# 3           INSTITUTO DE OFTALMOLOGIA DR. GAMA PINTO  2018  01
# 4           CENTRO HOSPITALAR PSIQUIÁTRICO DE LISBOA  2018  01
#
#                            Indicador Sub-indicador  Valor  \
# 0  Mediana do tempo de espera da LEC                116.0
# 1  Mediana do tempo de espera da LEC                146.0
# 2  Mediana do tempo de espera da LEC                 12.0
# 3  Mediana do tempo de espera da LEC                124.0
# 4  Mediana do tempo de espera da LEC                 42.0
#
#                                             Ficheiro
# 0  UGA RR 20180327 Indicadores Não Concluidos Tem...
# 1  UGA RR 20180327 Indicadores Não Concluidos Tem...
# 2  UGA RR 20180327 Indicadores Não Concluidos Tem...
# 3  UGA RR 20180327 Indicadores Não Concluidos Tem...
# 4  UGA RR 20180327 Indicadores Não Concluidos Tem...

# %% [markdown]
# ### df5

# %%
file_path = os.path.join('data', '1.17 %_Consultas CTH.xlsx')
sheet_name = "1.17_%Consultas CTH"

df5 = pd.read_excel(file_path, sheet_name=sheet_name)

df5 = df5[df5['Especialidades SICA'] == "Total s/ Medicina do Trabalho"]

df5 = df5.rename(columns={'Data (acumulado)':'data', 'Especialidades SICA':'Indicador'})

df5['Ano'] = df5.data.dt.year
df5['Mes'] = df5.data.dt.month

df5 = df5.drop(columns='data')

df5 = df5.set_index( ['Ano', 'Mes', 'Indicador'])

df5 = df5.stack().to_frame()

df5.columns = ['Valor']

df5 = df5.reset_index()

df5 = df5.rename(columns={'level_3':'Hospital'})

df5['Sub-indicador'] = ""
df5['Indicador'] = "Taxa de consultas realizadas via CTH"

df5['Ficheiro'] = "1.17 %_Consultas CTH.xlsx"

df5 = df5[['Hospital', 'Ano', 'Mes', 'Indicador', 'Sub-indicador', 'Valor', 'Ficheiro']]

# %%
df5.head()
# Out:
#                                             Hospital   Ano  Mes  \
# 0              Hospital Espírito Santo de Évora, EPE  2016    1
# 1      Unidade Local de Saúde do Baixo Alentejo, EPE  2016    1
# 2  Unidade Local de Saúde do Litoral Alentejano, EPE  2016    1
# 3    Unidade Local de Saúde do Norte Alentejano, EPE  2016    1
# 4    Centro Hospitalar Universitário do Algarve, EPE  2016    1
#
#                               Indicador Sub-indicador     Valor  \
# 0  Taxa de consultas realizadas via CTH                0.348507
# 1  Taxa de consultas realizadas via CTH                0.299900
# 2  Taxa de consultas realizadas via CTH                0.301338
# 3  Taxa de consultas realizadas via CTH                0.292039
# 4  Taxa de consultas realizadas via CTH                0.379994
#
#                     Ficheiro
# 0  1.17 %_Consultas CTH.xlsx
# 1  1.17 %_Consultas CTH.xlsx
# 2  1.17 %_Consultas CTH.xlsx
# 3  1.17 %_Consultas CTH.xlsx
# 4  1.17 %_Consultas CTH.xlsx

# %%
df5.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2156 entries, 0 to 2155
# Data columns (total 7 columns):
# Hospital         2156 non-null object
# Ano              2156 non-null int64
# Mes              2156 non-null int64
# Indicador        2156 non-null object
# Sub-indicador    2156 non-null object
# Valor            2156 non-null float64
# Ficheiro         2156 non-null object
# dtypes: float64(1), int64(2), object(4)
# memory usage: 118.0+ KB

# %% [markdown]
# ### df6

# %%
file_path = os.path.join('data', "1.14.RM, TAC, radioterapias, angiografias;.xlsx")

df6 = pd.read_excel(file_path, header=[0])

df6 = df6.stack().to_frame()

df6 = df6.reset_index(level=2)

df6.columns = ['Indicador', 'Valor']

df6['Indicador'] = df6['Indicador'].replace(to_replace={'Dentro da Estrutura': "MCDT's realizados dentro da estrutura", 
                                                        'Fora da Estrutura': "MCDT's realizados fora da estrutura"})

df6 = df6.reset_index()

df6 = df6.rename(columns={'level_0':'Sub-indicador', 'level_1':'data', 'level_2':'Hospital'})

df6['Ano'] = df6.data.dt.year
df6['Mes'] = df6.data.dt.month

df6['Ficheiro'] = "1.14.RM, TAC, radioterapias, angiografias;.xlsx"

df6 = df6[['Hospital', 'Ano', 'Mes', 'Indicador', 'Sub-indicador', 'Valor', 'Ficheiro']]

# %%
df6.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6352 entries, 0 to 6351
# Data columns (total 7 columns):
# Hospital         6352 non-null object
# Ano              6352 non-null int64
# Mes              6352 non-null int64
# Indicador        6352 non-null object
# Sub-indicador    6352 non-null object
# Valor            6352 non-null float64
# Ficheiro         6352 non-null object
# dtypes: float64(1), int64(2), object(4)
# memory usage: 347.5+ KB

# %%
df6.head()
# Out:
#                                             Hospital   Ano  Mes  \
# 0  Centro Hospitalar e Universitário de Coimbra, EPE  2014    3
# 1      Instituto Português Oncologia de Coimbra, EPE  2014    3
# 2  Centro Hospitalar Trás-os-Montes e Alto Douro,...  2014    3
# 3      Centro Hospitalar Universitário do Porto, EPE  2014    3
# 4       Centro Hospitalar Universitário S. João, EPE  2014    3
#
#                                Indicador     Sub-indicador   Valor  \
# 0  MCDT's realizados dentro da estrutura  Medicina Nuclear  3130.0
# 1  MCDT's realizados dentro da estrutura  Medicina Nuclear   676.0
# 2  MCDT's realizados dentro da estrutura  Medicina Nuclear     0.0
# 3  MCDT's realizados dentro da estrutura  Medicina Nuclear  1033.0
# 4  MCDT's realizados dentro da estrutura  Medicina Nuclear  1731.0
#
#                                           Ficheiro
# 0  1.14.RM, TAC, radioterapias, angiografias;.xlsx
# 1  1.14.RM, TAC, radioterapias, angiografias;.xlsx
# 2  1.14.RM, TAC, radioterapias, angiografias;.xlsx
# 3  1.14.RM, TAC, radioterapias, angiografias;.xlsx
# 4  1.14.RM, TAC, radioterapias, angiografias;.xlsx

# %% [markdown]
# ### df7

# %%
file_path = os.path.join('data', "1.10.Percentagem GDH Ambulatório em procedimentos ambulatorizaveis_.xlsx")

df7 = pd.DataFrame({'Hospital': [], 'Ano':[] , 'Mes':[] , 'Indicador':[] , 'Sub-indicador':[] , 'Valor':[], 'Ficheiro':[]})

for sheet in ['2016_2017', '2018_2019']:
    
    df_aux = pd.read_excel(file_path, sheet_name=sheet)

    df_aux.columns = ['Hospital', 'Ano', 'Mes', 'Valor']
    
    df_aux ['Sub-indicador'] = ""
    df_aux ['Indicador'] = "Taxa de GDH ambulatório em procedimentos ambulatorizáveis"
    
    df_aux['Ficheiro'] = "1.10.Percentagem GDH Ambulatório em procedimentos ambulatorizaveis_.xlsx"

    df_aux = df_aux[['Hospital', 'Ano', 'Mes', 'Indicador', 'Sub-indicador', 'Valor', 'Ficheiro']]
    
    df7 = df7.append(df_aux)

# %%
df7.head()
# Out:
#                                   Hospital     Ano  Mes  \
# 0  Centro Hospitalar Barreiro/Montijo, EPE  2016.0  1.0
# 1  Centro Hospitalar Barreiro/Montijo, EPE  2016.0  2.0
# 2  Centro Hospitalar Barreiro/Montijo, EPE  2016.0  3.0
# 3  Centro Hospitalar Barreiro/Montijo, EPE  2016.0  4.0
# 4  Centro Hospitalar Barreiro/Montijo, EPE  2016.0  5.0
#
#                                            Indicador Sub-indicador     Valor  \
# 0  Taxa de GDH ambulatório em procedimentos ambul...                0.780347
# 1  Taxa de GDH ambulatório em procedimentos ambul...                0.770492
# 2  Taxa de GDH ambulatório em procedimentos ambul...                0.790698
# 3  Taxa de GDH ambulatório em procedimentos ambul...                0.626087
# 4  Taxa de GDH ambulatório em procedimentos ambul...                0.748879
#
#                                             Ficheiro
# 0  1.10.Percentagem GDH Ambulatório em procedimen...
# 1  1.10.Percentagem GDH Ambulatório em procedimen...
# 2  1.10.Percentagem GDH Ambulatório em procedimen...
# 3  1.10.Percentagem GDH Ambulatório em procedimen...
# 4  1.10.Percentagem GDH Ambulatório em procedimen...

# %%
df7.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2520 entries, 0 to 1175
# Data columns (total 7 columns):
# Hospital         2520 non-null object
# Ano              2520 non-null float64
# Mes              2520 non-null float64
# Indicador        2520 non-null object
# Sub-indicador    2520 non-null object
# Valor            2297 non-null float64
# Ficheiro         2520 non-null object
# dtypes: float64(3), object(4)
# memory usage: 157.5+ KB

# %% [markdown]
# ### df8

# %%
file_path = os.path.join('data', "1.18.+1.19. % Cirurgias.xlsx")
sheet_name = "Cirurgias_1.18_1.19"

df8 = pd.read_excel(file_path, sheet_name=sheet_name, header = [0,1])

df8 = df8.stack(level=0)
df8 = df8.iloc[:,[0,1,2]]

df8 = df8.reset_index()

df8.columns = ['Hospital', 
               'data', 
               'Percentagem de cirurgias urgentes', 
               'Percentagem de cirurgias programadas feitas na produção adicional',
               'Percentagem de cirurgias programadas feitas na produção base']



df8['Ano'] = df8.data.dt.year
df8['Mes'] = df8.data.dt.month

df8 = df8.drop(columns='data')

df8 = df8.set_index( ['Ano', 'Mes', 'Hospital'])

df8 = df8.stack().to_frame()

df8.columns = ['Valor']

df8 = df8.reset_index()

df8 = df8.rename(columns={'level_3':'Indicador'})

df8['Sub-indicador'] = ""

df8['Ficheiro'] = "1.18.+1.19. % Cirurgias.xlsx"

df8 = df8[['Hospital', 'Ano', 'Mes', 'Indicador', 'Sub-indicador', 'Valor', 'Ficheiro']]

# %%
df8.head()
# Out:
#                                 Hospital   Ano  Mes  \
# 0  Hospital Espírito Santo de Évora, EPE  2015    1
# 1  Hospital Espírito Santo de Évora, EPE  2015    1
# 2  Hospital Espírito Santo de Évora, EPE  2015    1
# 3  Hospital Espírito Santo de Évora, EPE  2015    2
# 4  Hospital Espírito Santo de Évora, EPE  2015    2
#
#                                            Indicador Sub-indicador     Valor  \
# 0                  Percentagem de cirurgias urgentes                0.150327
# 1  Percentagem de cirurgias programadas feitas na...                0.267974
# 2  Percentagem de cirurgias programadas feitas na...                0.581699
# 3                  Percentagem de cirurgias urgentes                0.140582
# 4  Percentagem de cirurgias programadas feitas na...                0.250412
#
#                        Ficheiro
# 0  1.18.+1.19. % Cirurgias.xlsx
# 1  1.18.+1.19. % Cirurgias.xlsx
# 2  1.18.+1.19. % Cirurgias.xlsx
# 3  1.18.+1.19. % Cirurgias.xlsx
# 4  1.18.+1.19. % Cirurgias.xlsx

# %%
df8.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7740 entries, 0 to 7739
# Data columns (total 7 columns):
# Hospital         7740 non-null object
# Ano              7740 non-null int64
# Mes              7740 non-null int64
# Indicador        7740 non-null object
# Sub-indicador    7740 non-null object
# Valor            7740 non-null float64
# Ficheiro         7740 non-null object
# dtypes: float64(1), int64(2), object(4)
# memory usage: 423.4+ KB

# %% [markdown]
# ### df9

# %%
file_path = os.path.join('data', "1.5.Taxa_de_Cirurgias de ambulatório, por especialidade_2014_2019.xlsx")
sheet_name = "1.5.Tx_Cir.Amb_especiali_18_19"

df9 = pd.DataFrame({'Hospital': [], 'Ano':[] , 'Mes':[] , 'Indicador':[] , 'Sub-indicador':[] , 'Valor':[], 'Ficheiro':[]})
df_aux = None

for sheet in [0,1,2]:
    
    df_aux = pd.read_excel(file_path, sheet_name=sheet, header = [0,1])

    df_aux = df_aux.stack(level=0)

    df_aux = df_aux.loc[:,['Total s/ Medicina do Trabalho']]

    df_aux['Indicador'] = "Taxa de cirurgias de ambulatório"

    df_aux = df_aux.rename(columns={'Total s/ Medicina do Trabalho':'Valor'})

    df_aux = df_aux.reset_index()


    df_aux = df_aux.rename(columns={'level_0':'Hospital', 'level_1':'data'})

    df_aux['Ano'] = df_aux.data.dt.year
    df_aux['Mes'] = df_aux.data.dt.month

    df_aux = df_aux.drop(columns='data')

    df_aux['Sub-indicador'] = ""
    
    df_aux['Ficheiro'] = "1.5.Taxa_de_Cirurgias de ambulatório, por especialidade_2014_2019.xlsx"

    df_aux = df_aux[['Hospital', 'Ano', 'Mes', 'Indicador', 'Sub-indicador', 'Valor', 'Ficheiro']]
    
    df9 = df9.append(df_aux)
    df_aux = None

# %%
df9.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3095 entries, 0 to 1031
# Data columns (total 7 columns):
# Hospital         3095 non-null object
# Ano              3095 non-null float64
# Mes              3095 non-null float64
# Indicador        3095 non-null object
# Sub-indicador    3095 non-null object
# Valor            3095 non-null float64
# Ficheiro         3095 non-null object
# dtypes: float64(3), object(4)
# memory usage: 193.4+ KB

# %% [markdown]
# ### df10

# %%
file_path = os.path.join('data', "1.6.Taxa de ocupação de Bloco Operatório_2014_2019.xlsx")

df10 = pd.DataFrame({'Hospital': [], 'Ano':[] , 'Mes':[] , 'Indicador':[] , 'Sub-indicador':[] , 'Valor':[], 'Ficheiro':[]})
df_aux = None

for sheet in [0,1,2]:
    
    df_aux = pd.read_excel(file_path, sheet_name=sheet, header=0)
    
    df_aux = df_aux.rename(columns={'Instituição':'Hospital', 'Mês':'Mes'})
    
    df_aux['Indicador'] = "Taxa de ocupação de bloco operatório"
    df_aux['Sub-indicador'] = ""
    
    df_aux['Ficheiro'] = "1.6.Taxa de ocupação de Bloco Operatório_2014_2019.xlsx"

    df_aux = df_aux[['Hospital', 'Ano', 'Mes', 'Indicador', 'Sub-indicador', 'Valor', 'Ficheiro']]
    
    df10 = df10.append(df_aux)
    df_aux = None

# %%
df10.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3843 entries, 0 to 1154
# Data columns (total 7 columns):
# Hospital         3843 non-null object
# Ano              3843 non-null float64
# Mes              3843 non-null float64
# Indicador        3843 non-null object
# Sub-indicador    3843 non-null object
# Valor            1005 non-null float64
# Ficheiro         3843 non-null object
# dtypes: float64(3), object(4)
# memory usage: 240.2+ KB

# %%
df10.head()
# Out:
#                                   Hospital     Ano  Mes  \
# 0  Centro Hospitalar Barreiro/Montijo, EPE  2014.0  1.0
# 1  Centro Hospitalar Barreiro/Montijo, EPE  2014.0  2.0
# 2  Centro Hospitalar Barreiro/Montijo, EPE  2014.0  3.0
# 3  Centro Hospitalar Barreiro/Montijo, EPE  2014.0  4.0
# 4  Centro Hospitalar Barreiro/Montijo, EPE  2014.0  5.0
#
#                               Indicador Sub-indicador  Valor  \
# 0  Taxa de ocupação de bloco operatório                  NaN
# 1  Taxa de ocupação de bloco operatório                  NaN
# 2  Taxa de ocupação de bloco operatório                  NaN
# 3  Taxa de ocupação de bloco operatório                  NaN
# 4  Taxa de ocupação de bloco operatório                  NaN
#
#                                             Ficheiro
# 0  1.6.Taxa de ocupação de Bloco Operatório_2014_...
# 1  1.6.Taxa de ocupação de Bloco Operatório_2014_...
# 2  1.6.Taxa de ocupação de Bloco Operatório_2014_...
# 3  1.6.Taxa de ocupação de Bloco Operatório_2014_...
# 4  1.6.Taxa de ocupação de Bloco Operatório_2014_...

# %% [markdown]
# ### df11

# %%
file_path = os.path.join('data', "1.7.Taxa de Ocupação do Internamento.xlsx")
sheet_name = "Tx ocupação"

df11 = pd.read_excel(file_path, sheet_name=sheet_name)

df11 = df11.rename(columns={'Mês':'Mes'})

df11 =  df11.set_index(['Ano', 'Mes'])

df11= df11.stack().to_frame()

df11.columns = ['Valor']

df11 = df11.reset_index()

df11 = df11.rename(columns={'level_2':'Hospital'})

df11['Indicador'] = "Taxa de ocupação do internamento"
df11['Sub-indicador'] = ""

df11['Ficheiro'] = "1.7.Taxa de Ocupação do Internamento.xlsx"

df11 = df11[['Hospital', 'Ano', 'Mes', 'Indicador', 'Sub-indicador', 'Valor', 'Ficheiro']]

# %%
df11.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3525 entries, 0 to 3524
# Data columns (total 7 columns):
# Hospital         3525 non-null object
# Ano              3525 non-null int64
# Mes              3525 non-null object
# Indicador        3525 non-null object
# Sub-indicador    3525 non-null object
# Valor            3525 non-null object
# Ficheiro         3525 non-null object
# dtypes: int64(1), object(6)
# memory usage: 192.9+ KB

# %%
df11.head()
# Out:
#                                             Hospital   Ano      Mes  \
# 0  Unidade Local de Saúde do Litoral Alentejano, EPE  2014  Janeiro
# 1              Hospital Espírito Santo de Évora, EPE  2014  Janeiro
# 2    Unidade Local de Saúde do Norte Alentejano, EPE  2014  Janeiro
# 3      Unidade Local de Saúde do Baixo Alentejo, EPE  2014  Janeiro
# 4    Centro Hospitalar Universitário do Algarve, EPE  2014  Janeiro
#
#                           Indicador Sub-indicador  Valor  \
# 0  Taxa de ocupação do internamento                0.948
# 1  Taxa de ocupação do internamento                0.731
# 2  Taxa de ocupação do internamento                0.907
# 3  Taxa de ocupação do internamento                0.796
# 4  Taxa de ocupação do internamento                 0.88
#
#                                     Ficheiro
# 0  1.7.Taxa de Ocupação do Internamento.xlsx
# 1  1.7.Taxa de Ocupação do Internamento.xlsx
# 2  1.7.Taxa de Ocupação do Internamento.xlsx
# 3  1.7.Taxa de Ocupação do Internamento.xlsx
# 4  1.7.Taxa de Ocupação do Internamento.xlsx

# %% [markdown]
# ### df12

# %%
file_path = os.path.join('data', "1.3.2. %_Ep_acima_limiar_máximo.xlsx")

df12 = pd.DataFrame({'Hospital': [], 'Ano':[] , 'Mes':[] , 'Indicador':[] , 'Sub-indicador':[] , 'Valor':[], 'Ficheiro':[]})
df_aux = None

for sheet in [0,1,2,3,4,5]:

    df_aux = pd.read_excel(file_path, sheet_name=sheet, header=[0,1,2])

    df_aux.columns = df_aux.columns.droplevel(0)

    df_aux = df_aux.stack(level=0)

    df_aux['Valor'] = df_aux.Num/df_aux.Den

    df_aux = df_aux.drop(columns=['Den', 'Num'])

    df_aux = df_aux.reset_index()

    df_aux = df_aux.rename(columns={'level_0':'Hospital', 'level_1':'data'})

    df_aux['data'] = df_aux['data'].astype(str)

    df_aux['Ano'] = df_aux['data'].str.slice(start=0, stop=4)
    df_aux['Mes'] = df_aux['data'].str.slice(start=4)

    df_aux.columns.name = ""

    df_aux = df_aux.drop(columns="data")

    df_aux['Indicador'] = "Taxa de episódios com duração de internamento acima do limiar máximo"
    df_aux['Sub-indicador'] = ""

    df_aux['Ficheiro'] = "1.3.2. %_Ep_acima_limiar_máximo.xlsx"

    df_aux = df_aux[['Hospital', 'Ano', 'Mes', 'Indicador', 'Sub-indicador', 'Valor', 'Ficheiro']]
    
    df12 = df12.append(df_aux)
    df_aux = None

# %%
df12.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3632 entries, 0 to 560
# Data columns (total 7 columns):
# Hospital         3632 non-null object
# Ano              3632 non-null object
# Mes              3632 non-null object
# Indicador        3632 non-null object
# Sub-indicador    3632 non-null object
# Valor            3317 non-null float64
# Ficheiro         3632 non-null object
# dtypes: float64(1), object(6)
# memory usage: 227.0+ KB

# %%
df12.head()
# Out:
#                                   Hospital   Ano Mes  \
# 0  Centro Hospitalar Barreiro/Montijo, EPE  2014  01
# 1  Centro Hospitalar Barreiro/Montijo, EPE  2014  02
# 2  Centro Hospitalar Barreiro/Montijo, EPE  2014  03
# 3  Centro Hospitalar Barreiro/Montijo, EPE  2014  04
# 4  Centro Hospitalar Barreiro/Montijo, EPE  2014  05
#
#                                            Indicador Sub-indicador     Valor  \
# 0  Taxa de episódios com duração de internamento ...                0.021795
# 1  Taxa de episódios com duração de internamento ...                0.019079
# 2  Taxa de episódios com duração de internamento ...                0.016522
# 3  Taxa de episódios com duração de internamento ...                0.018311
# 4  Taxa de episódios com duração de internamento ...                0.019810
#
#                                Ficheiro
# 0  1.3.2. %_Ep_acima_limiar_máximo.xlsx
# 1  1.3.2. %_Ep_acima_limiar_máximo.xlsx
# 2  1.3.2. %_Ep_acima_limiar_máximo.xlsx
# 3  1.3.2. %_Ep_acima_limiar_máximo.xlsx
# 4  1.3.2. %_Ep_acima_limiar_máximo.xlsx

# %% [markdown]
# ### df13

# %%
file_path = os.path.join('data', "1.20.Número e % de MCDT requisitados pelo exterior;.xlsx")
sheet_name = "mcdt total"

df13 = pd.read_excel(file_path, sheet_name=sheet_name)

df13 = df13.loc[df13.D=="Total Serviços",:]

df13['Ano'] = df13.C.str.slice(start=-4)
df13['Mes'] = df13.C.str.slice(start=1, stop=3).astype(int)*3

df13 = df13.drop(columns=['B', 'C', 'D'])

df13 =  df13.set_index(['Ano', 'Mes'])

df13= df13.stack().to_frame()

df13.columns = ['Valor']

df13 = df13.reset_index()

df13 = df13.rename(columns={'level_2':'Hospital'})

df13['Indicador'] = "Número total de MCDT's (dentro da estrutura)"
df13['Sub-indicador'] = ""

df13['Ficheiro'] = "1.20.Número e % de MCDT requisitados pelo exterior;.xlsx"

df13 = df13[['Hospital', 'Ano', 'Mes', 'Indicador', 'Sub-indicador', 'Valor', 'Ficheiro']]

# %%
df13.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 977 entries, 0 to 976
# Data columns (total 7 columns):
# Hospital         977 non-null object
# Ano              977 non-null object
# Mes              977 non-null int64
# Indicador        977 non-null object
# Sub-indicador    977 non-null object
# Valor            977 non-null float64
# Ficheiro         977 non-null object
# dtypes: float64(1), int64(1), object(5)
# memory usage: 53.5+ KB

# %%
df13.head()
# Out:
#                                             Hospital   Ano  Mes  \
# 0              Hospital Espírito Santo de Évora, EPE  2014    3
# 1      Unidade Local de Saúde do Baixo Alentejo, EPE  2014    3
# 2  Unidade Local de Saúde do Litoral Alentejano, EPE  2014    3
# 3    Unidade Local de Saúde do Norte Alentejano, EPE  2014    3
# 4    Centro Hospitalar Universitário do Algarve, EPE  2014    3
#
#                                       Indicador Sub-indicador     Valor  \
# 0  Número total de MCDT's (dentro da estrutura)                765091.0
# 1  Número total de MCDT's (dentro da estrutura)                367881.0
# 2  Número total de MCDT's (dentro da estrutura)                292340.0
# 3  Número total de MCDT's (dentro da estrutura)                572916.0
# 4  Número total de MCDT's (dentro da estrutura)                913324.0
#
#                                             Ficheiro
# 0  1.20.Número e % de MCDT requisitados pelo exte...
# 1  1.20.Número e % de MCDT requisitados pelo exte...
# 2  1.20.Número e % de MCDT requisitados pelo exte...
# 3  1.20.Número e % de MCDT requisitados pelo exte...
# 4  1.20.Número e % de MCDT requisitados pelo exte...

# %% [markdown]
# ### df14

# %%
file_path = os.path.join('data', "1.20.Número e % de MCDT requisitados pelo exterior;.xlsx")
sheet_name = "prct mcdt ext"

df14 = pd.read_excel(file_path, sheet_name=sheet_name)

df14['Ano'] = df14.D.str.slice(start=-4)
df14['Mes'] = df14.D.str.slice(start=1, stop=3).astype(int)*3

df14 = df14.drop(columns=['B', 'C', 'D'])

df14 =  df14.set_index(['Ano', 'Mes'])

df14= df14.stack().to_frame()

df14.columns = ['Valor']

df14 = df14.reset_index()

df14 = df14.rename(columns={'level_2':'Hospital'})

df14['Indicador'] = "Percentagem de MCDT's requisitados pelo exterior"
df14['Sub-indicador'] = ""

df14['Ficheiro'] = "1.20.Número e % de MCDT requisitados pelo exterior;.xlsx"

df14 = df14[['Hospital', 'Ano', 'Mes', 'Indicador', 'Sub-indicador', 'Valor', 'Ficheiro']]

# %%
df14.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 977 entries, 0 to 976
# Data columns (total 7 columns):
# Hospital         977 non-null object
# Ano              977 non-null object
# Mes              977 non-null int64
# Indicador        977 non-null object
# Sub-indicador    977 non-null object
# Valor            977 non-null float64
# Ficheiro         977 non-null object
# dtypes: float64(1), int64(1), object(5)
# memory usage: 53.5+ KB

# %%
df14.head()
# Out:
#                                             Hospital   Ano  Mes  \
# 0              Hospital Espírito Santo de Évora, EPE  2014    3
# 1      Unidade Local de Saúde do Baixo Alentejo, EPE  2014    3
# 2  Unidade Local de Saúde do Litoral Alentejano, EPE  2014    3
# 3    Unidade Local de Saúde do Norte Alentejano, EPE  2014    3
# 4    Centro Hospitalar Universitário do Algarve, EPE  2014    3
#
#                                           Indicador Sub-indicador     Valor  \
# 0  Percentagem de MCDT's requisitados pelo exterior                0.074400
# 1  Percentagem de MCDT's requisitados pelo exterior                0.167288
# 2  Percentagem de MCDT's requisitados pelo exterior                0.190347
# 3  Percentagem de MCDT's requisitados pelo exterior                0.266545
# 4  Percentagem de MCDT's requisitados pelo exterior                0.000000
#
#                                             Ficheiro
# 0  1.20.Número e % de MCDT requisitados pelo exte...
# 1  1.20.Número e % de MCDT requisitados pelo exte...
# 2  1.20.Número e % de MCDT requisitados pelo exte...
# 3  1.20.Número e % de MCDT requisitados pelo exte...
# 4  1.20.Número e % de MCDT requisitados pelo exte...

# %% [markdown]
# ### df15

# %%
file_path = os.path.join('data', "Total Indicadores.xlsx")

df15 = pd.read_excel(file_path)

df15['Ficheiro'] = "Total Indicadores.xlsx"

df15 = df15.reset_index(drop=True)

# %%
df15.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 54164 entries, 0 to 54163
# Data columns (total 7 columns):
# Hospital         54164 non-null object
# Ano              54164 non-null int64
# Mes              54164 non-null int64
# Indicador        54164 non-null object
# Sub-indicador    0 non-null float64
# Valor            52605 non-null float64
# Ficheiro         54164 non-null object
# dtypes: float64(2), int64(2), object(3)
# memory usage: 2.9+ MB

# %%
df15.head()
# Out:
#                                             Hospital   Ano  Mês  \
# 0    Unidade Local de Saúde do Norte Alentejano, EPE  2014    1
# 1  Centro Hospitalar e Universitário de Coimbra, EPE  2014    1
# 2                       Hospital Garcia de Orta, EPE  2014    1
# 3      Centro Hospitalar Universitário do Porto, EPE  2014    1
# 4         Centro Hospitalar Entre Douro e Vouga, EPE  2014    1
#
#                         Indicador  Sub-indicador    Valor  \
# 0  Total de episódios de urgência            NaN   8714.0
# 1  Total de episódios de urgência            NaN  24072.0
# 2  Total de episódios de urgência            NaN  12920.0
# 3  Total de episódios de urgência            NaN  11324.0
# 4  Total de episódios de urgência            NaN  15633.0
#
#                  Ficheiro
# 0  Total Indicadores.xlsx
# 1  Total Indicadores.xlsx
# 2  Total Indicadores.xlsx
# 3  Total Indicadores.xlsx
# 4  Total Indicadores.xlsx

# %% [markdown]
# # Append all dataframes

# %%
df_list = [df1, df2, df3, df4, df5, df6, df7, df8, df9, df10, df11, df12, df13, df14, df15]

#df_list = [var for var in dir() if type(var) is str and var[:2]=='df' and var[2].isnumeric() and var != "df_aux"]

df_all = pd.DataFrame({'Hospital': [], 'Ano':[] , 'Mes':[] , 'Indicador':[] , 'Sub-indicador':[] , 'Valor':[], 'Ficheiro':[]})

for dfi in df_list:
    df_all = df_all.append(dfi)


df_all = df_all.reset_index(drop=True)

# %%
df_all.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119402 entries, 0 to 119401
# Data columns (total 7 columns):
# Hospital         118838 non-null object
# Ano              119402 non-null object
# Mes              119402 non-null object
# Indicador        119402 non-null object
# Sub-indicador    65238 non-null object
# Valor            114387 non-null object
# Ficheiro         119402 non-null object
# dtypes: object(7)
# memory usage: 6.4+ MB

# %%
df_all
# Out:
#                                                  Hospital   Ano Mes  \
# 0                 Centro Hospitalar Barreiro/Montijo, EPE  2014   1
# 1                 Centro Hospitalar Barreiro/Montijo, EPE  2014   2
# 2                 Centro Hospitalar Barreiro/Montijo, EPE  2014   3
# 3                 Centro Hospitalar Barreiro/Montijo, EPE  2014   4
# 4                 Centro Hospitalar Barreiro/Montijo, EPE  2014   5
# 5                 Centro Hospitalar Barreiro/Montijo, EPE  2014   6
# 6                 Centro Hospitalar Barreiro/Montijo, EPE  2014   7
# 7                 Centro Hospitalar Barreiro/Montijo, EPE  2014   8
# 8                 Centro Hospitalar Barreiro/Montijo, EPE  2014   9
# 9                 Centro Hospitalar Barreiro/Montijo, EPE  2014  10
# 10                Centro Hospitalar Barreiro/Montijo, EPE  2014  11
# 11                Centro Hospitalar Barreiro/Montijo, EPE  2014  12
# 12                Centro Hospitalar Barreiro/Montijo, EPE  2015   1
# 13                Centro Hospitalar Barreiro/Montijo, EPE  2015   2
# 14                Centro Hospitalar Barreiro/Montijo, EPE  2015   3
# 15                Centro Hospitalar Barreiro/Montijo, EPE  2015   4
# 16                Centro Hospitalar Barreiro/Montijo, EPE  2015   5
# 17                Centro Hospitalar Barreiro/Montijo, EPE  2015   6
# 18                Centro Hospitalar Barreiro/Montijo, EPE  2015   7
# 19                Centro Hospitalar Barreiro/Montijo, EPE  2015   8
# 20                Centro Hospitalar Barreiro/Montijo, EPE  2015   9
# 21                Centro Hospitalar Barreiro/Montijo, EPE  2015  10
# 22                Centro Hospitalar Barreiro/Montijo, EPE  2015  11
# 23                Centro Hospitalar Barreiro/Montijo, EPE  2015  12
# 24                Centro Hospitalar Barreiro/Montijo, EPE  2016   1
# 25                Centro Hospitalar Barreiro/Montijo, EPE  2016   2
# 26                Centro Hospitalar Barreiro/Montijo, EPE  2016   3
# 27                Centro Hospitalar Barreiro/Montijo, EPE  2016   4
# 28                Centro Hospitalar Barreiro/Montijo, EPE  2016   5
# 29                Centro Hospitalar Barreiro/Montijo, EPE  2016   6
# ...                                                   ...   ...  ..
# 119372         Centro Hospitalar Entre Douro e Vouga, EPE  2019   8
# 119373          Unidade Local de Saúde de Matosinhos, EPE  2019   8
# 119374          Unidade Local de Saúde do Alto Minho, EPE  2019   8
# 119375  Unidade Local de Saúde do Litoral Alentejano, EPE  2019   9
# 119376              Centro Hospitalar do Baixo Vouga, EPE  2019   9
# 119377         Hospital Distrital da Figueira da Foz, EPE  2019   9
# 119378            Centro Hospitalar Barreiro/Montijo, EPE  2019   9
# 119379  Centro Hospitalar Universitário Lisboa Central...  2019   9
# 119380                  Centro Hospitalar Médio Tejo, EPE  2019   9
# 119381                           Hospital de Cascais, PPP  2019   9
# 119382                               Instituto Gama Pinto  2019   9
# 119383      Centro Hospitalar Universitário do Porto, EPE  2019   9
# 119384     Centro Hospitalar Universitário do Algarve,EPE  2019  10
# 119385  Centro Medicina de Reabilitação da Região Cent...  2019  10
# 119386  Centro Hospitalar Universitário Lisboa Central...  2019  10
# 119387                    Centro Hospitalar do Oeste, EPE  2019  10
# 119388               Hospital de Vila Franca de Xira, PPP  2019  10
# 119389   Centro Hospitalar Vila Nova de Gaia/Espinho, EPE  2019  10
# 119390                             Hospital de Braga, EPE  2019  10
# 119391                   Centro Hospitalar de Leiria, EPE  2019  11
# 119392                 Hospital Arcebispo João Crisóstomo  2019  11
# 119393                      Hospital Dr. Francisco Zagalo  2019  11
# 119394      Instituto Português Oncologia de Coimbra, EPE  2019  11
# 119395         Centro Hospitalar de Lisboa Ocidental, EPE  2019  11
# 119396                  Centro Hospitalar de Setúbal, EPE  2019  11
# 119397               Hospital de Vila Franca de Xira, PPP  2019  11
# 119398       Instituto Português Oncologia de Lisboa, EPE  2019  11
# 119399              Centro Hospitalar Tâmega e Sousa, EPE  2019  11
# 119400  Centro Hospitalar Trás-os-Montes e Alto Douro,...  2019  11
# 119401    Hospital da Senhora da Oliveira, Guimarães, EPE  2019  11
#
#                                                 Indicador Sub-indicador  \
# 0                   Número de doentes saídos por cama/mês
# 1                   Número de doentes saídos por cama/mês
# 2                   Número de doentes saídos por cama/mês
# 3                   Número de doentes saídos por cama/mês
# 4                   Número de doentes saídos por cama/mês
# 5                   Número de doentes saídos por cama/mês
# 6                   Número de doentes saídos por cama/mês
# 7                   Número de doentes saídos por cama/mês
# 8                   Número de doentes saídos por cama/mês
# 9                   Número de doentes saídos por cama/mês
# 10                  Número de doentes saídos por cama/mês
# 11                  Número de doentes saídos por cama/mês
# 12                  Número de doentes saídos por cama/mês
# 13                  Número de doentes saídos por cama/mês
# 14                  Número de doentes saídos por cama/mês
# 15                  Número de doentes saídos por cama/mês
# 16                  Número de doentes saídos por cama/mês
# 17                  Número de doentes saídos por cama/mês
# 18                  Número de doentes saídos por cama/mês
# 19                  Número de doentes saídos por cama/mês
# 20                  Número de doentes saídos por cama/mês
# 21                  Número de doentes saídos por cama/mês
# 22                  Número de doentes saídos por cama/mês
# 23                  Número de doentes saídos por cama/mês
# 24                  Número de doentes saídos por cama/mês
# 25                  Número de doentes saídos por cama/mês
# 26                  Número de doentes saídos por cama/mês
# 27                  Número de doentes saídos por cama/mês
# 28                  Número de doentes saídos por cama/mês
# 29                  Número de doentes saídos por cama/mês
# ...                                                   ...           ...
# 119372  Percentagem de cirurgias da anca efetuadas nas...           NaN
# 119373  Percentagem de cirurgias da anca efetuadas nas...           NaN
# 119374  Percentagem de cirurgias da anca efetuadas nas...           NaN
# 119375  Percentagem de cirurgias da anca efetuadas nas...           NaN
# 119376  Percentagem de cirurgias da anca efetuadas nas...           NaN
# 119377  Percentagem de cirurgias da anca efetuadas nas...           NaN
# 119378  Percentagem de cirurgias da anca efetuadas nas...           NaN
# 119379  Percentagem de cirurgias da anca efetuadas nas...           NaN
# 119380  Percentagem de cirurgias da anca efetuadas nas...           NaN
# 119381  Percentagem de cirurgias da anca efetuadas nas...           NaN
# 119382  Percentagem de cirurgias da anca efetuadas nas...           NaN
# 119383  Percentagem de cirurgias da anca efetuadas nas...           NaN
# 119384  Percentagem de cirurgias da anca efetuadas nas...           NaN
# 119385  Percentagem de cirurgias da anca efetuadas nas...           NaN
# 119386  Percentagem de cirurgias da anca efetuadas nas...           NaN
# 119387  Percentagem de cirurgias da anca efetuadas nas...           NaN
# 119388  Percentagem de cirurgias da anca efetuadas nas...           NaN
# 119389  Percentagem de cirurgias da anca efetuadas nas...           NaN
# 119390  Percentagem de cirurgias da anca efetuadas nas...           NaN
# 119391  Percentagem de cirurgias da anca efetuadas nas...           NaN
# 119392  Percentagem de cirurgias da anca efetuadas nas...           NaN
# 119393  Percentagem de cirurgias da anca efetuadas nas...           NaN
# 119394  Percentagem de cirurgias da anca efetuadas nas...           NaN
# 119395  Percentagem de cirurgias da anca efetuadas nas...           NaN
# 119396  Percentagem de cirurgias da anca efetuadas nas...           NaN
# 119397  Percentagem de cirurgias da anca efetuadas nas...           NaN
# 119398  Percentagem de cirurgias da anca efetuadas nas...           NaN
# 119399  Percentagem de cirurgias da anca efetuadas nas...           NaN
# 119400  Percentagem de cirurgias da anca efetuadas nas...           NaN
# 119401  Percentagem de cirurgias da anca efetuadas nas...           NaN
#
#           Valor                              Ficheiro
# 0       86.6154  1.8.Doentes Saidos por cama_mês.xlsx
# 1       2.97183  1.8.Doentes Saidos por cama_mês.xlsx
# 2       3.12958  1.8.Doentes Saidos por cama_mês.xlsx
# 3       2.90936  1.8.Doentes Saidos por cama_mês.xlsx
# 4       3.12573  1.8.Doentes Saidos por cama_mês.xlsx
# 5       3.03509  1.8.Doentes Saidos por cama_mês.xlsx
# 6       2.95322  1.8.Doentes Saidos por cama_mês.xlsx
# 7       2.87135  1.8.Doentes Saidos por cama_mês.xlsx
# 8       2.76023  1.8.Doentes Saidos por cama_mês.xlsx
# 9       3.22515  1.8.Doentes Saidos por cama_mês.xlsx
# 10      2.90058  1.8.Doentes Saidos por cama_mês.xlsx
# 11      3.23662  1.8.Doentes Saidos por cama_mês.xlsx
# 12      3.05995  1.8.Doentes Saidos por cama_mês.xlsx
# 13      2.85014  1.8.Doentes Saidos por cama_mês.xlsx
# 14      3.24796  1.8.Doentes Saidos por cama_mês.xlsx
# 15      3.14986  1.8.Doentes Saidos por cama_mês.xlsx
# 16      2.91268  1.8.Doentes Saidos por cama_mês.xlsx
# 17      2.89474  1.8.Doentes Saidos por cama_mês.xlsx
# 18      2.85673  1.8.Doentes Saidos por cama_mês.xlsx
# 19      2.79825  1.8.Doentes Saidos por cama_mês.xlsx
# 20      3.10375  1.8.Doentes Saidos por cama_mês.xlsx
# 21      3.14409  1.8.Doentes Saidos por cama_mês.xlsx
# 22      2.97118  1.8.Doentes Saidos por cama_mês.xlsx
# 23      3.18732  1.8.Doentes Saidos por cama_mês.xlsx
# 24      3.03064  1.8.Doentes Saidos por cama_mês.xlsx
# 25      2.88858  1.8.Doentes Saidos por cama_mês.xlsx
# 26       3.2507  1.8.Doentes Saidos por cama_mês.xlsx
# 27      3.16854  1.8.Doentes Saidos por cama_mês.xlsx
# 28      3.53602  1.8.Doentes Saidos por cama_mês.xlsx
# 29      3.23919  1.8.Doentes Saidos por cama_mês.xlsx
# ...         ...                                   ...
# 119372   0.1975                Total Indicadores.xlsx
# 119373   0.4396                Total Indicadores.xlsx
# 119374   0.5442                Total Indicadores.xlsx
# 119375        0                Total Indicadores.xlsx
# 119376    0.731                Total Indicadores.xlsx
# 119377   0.6118                Total Indicadores.xlsx
# 119378   0.3135                Total Indicadores.xlsx
# 119379   0.3538                Total Indicadores.xlsx
# 119380   0.2227                Total Indicadores.xlsx
# 119381   0.8958                Total Indicadores.xlsx
# 119382        0                Total Indicadores.xlsx
# 119383   0.2832                Total Indicadores.xlsx
# 119384   0.1682                Total Indicadores.xlsx
# 119385        0                Total Indicadores.xlsx
# 119386    0.411                Total Indicadores.xlsx
# 119387        0                Total Indicadores.xlsx
# 119388   0.5469                Total Indicadores.xlsx
# 119389   0.5242                Total Indicadores.xlsx
# 119390   0.3571                Total Indicadores.xlsx
# 119391   0.3874                Total Indicadores.xlsx
# 119392        0                Total Indicadores.xlsx
# 119393        0                Total Indicadores.xlsx
# 119394        0                Total Indicadores.xlsx
# 119395      0.2                Total Indicadores.xlsx
# 119396   0.5596                Total Indicadores.xlsx
# 119397   0.5469                Total Indicadores.xlsx
# 119398        0                Total Indicadores.xlsx
# 119399   0.6095                Total Indicadores.xlsx
# 119400   0.6291                Total Indicadores.xlsx
# 119401   0.4721                Total Indicadores.xlsx
#
# [119402 rows x 7 columns]

# %% [markdown]
# # Clean Values

# %%
df_clean = df_all.copy()

# %%
df_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119402 entries, 0 to 119401
# Data columns (total 7 columns):
# Hospital         118838 non-null object
# Ano              119402 non-null object
# Mes              119402 non-null object
# Indicador        119402 non-null object
# Sub-indicador    65238 non-null object
# Valor            114387 non-null object
# Ficheiro         119402 non-null object
# dtypes: object(7)
# memory usage: 6.4+ MB

# %% [markdown]
# #### Converte 'Ano' para numérico

# %%
df_clean['Ano'] = pd.to_numeric(df_clean['Ano'], errors='raise', downcast='integer')

# %% [markdown]
# #### Converte 'Mes' para numérico

# %%
map_dict = ({'Janeiro': 1, 
             'Fevereiro': 2,
             'Março': 3,
             'Abril': 4,
             'Maio': 5,
             'Junho': 6,
             'Julho': 7,
             'Agosto': 8,
             'Setembro': 9,
             'Outubro': 10,
             'Novembro': 11,
             'Dezembro':12})

df_clean['Mes'] = df_clean['Mes'].replace(to_replace=map_dict)

df_clean['Mes'] = pd.to_numeric(df_clean['Mes'], errors='raise', downcast='integer')

# %% [markdown]
# #### Elimina linhas sem descrição do Hospital

# %%
df_clean['Hospital'].isna().sum()
# Out:
# 564

# %%
df_clean = df_clean.dropna(axis=0, subset=['Hospital'])

# %% [markdown]
# #### Elimina caracteres não numéricos da coluna 'Valor'

# %%
df_clean['Valor'].isna().sum()
# Out:
# 5015

# %%
df_clean = df_clean.dropna(axis=0, subset=['Valor'])

# %%
df_clean['Valor'] = df_clean['Valor'].astype(str).str.replace(r'%', r'',regex=True)

# %%
df_clean['Valor'] = df_clean['Valor'].astype(str).str.replace(r',', r'.',regex=True)

# %%
df_clean['Valor'] = pd.to_numeric(df_clean['Valor'], errors='raise')

# %%
#df_clean.to_excel("Dados consolidados.xlsx", index=False)

# %% [markdown]
# # Indicadores calculados

# %%
df_aux = df_clean.copy()

# %%
df_aux.Indicador.unique()
# Out:
# array(['Número de doentes saídos por cama/mês',
#        'Mediana do tempo de espera da LIC',
#        'Percentagem de utentes em LIC dentro do TMRG',
#        'Média do tempo de espera dos operados',
#        'Percentagem de doentes operados dentro dos TMRG',
#        'Taxa de disponibilidade do bloco operatório',
#        'Número de cirurgias por especialista de cirurgia',
#        'Número de cirurgias por anestesiologista',
#        'Índice de demora média ajustada',
#        'Mediana do tempo de espera da LEC',
#        'Taxa de consultas realizadas via CTH',
#        "MCDT's realizados dentro da estrutura",
#        "MCDT's realizados fora da estrutura",
#        'Taxa de GDH ambulatório em procedimentos ambulatorizáveis',
#        'Percentagem de cirurgias urgentes',
#        'Percentagem de cirurgias programadas feitas na produção adicional',
#        'Percentagem de cirurgias programadas feitas na produção base',
#        'Taxa de cirurgias de ambulatório',
#        'Taxa de ocupação de bloco operatório',
#        'Taxa de ocupação do internamento',
#        'Taxa de episódios com duração de internamento acima do limiar máximo',
#        "Número total de MCDT's (dentro da estrutura)",
#        "Percentagem de MCDT's requisitados pelo exterior",
#        'Total de episódios de urgência', 'Doentes saídos', 'Demora média',
#        'Demora média antes da cirurgia',
#        'Total Consultas Externas (s/ Medicina do Trabalho)',
#        'Primeiras consultas', 'Consultas subsequentes',
#        'Primeiras consultas no total de consultas ',
#        'Cirurgias Programadas', 'Cirurgias convencionais',
#        'Cirurgias ambulatórias', 'Cirurgias urgentes',
#        'Percentagem de atendimentos urgentes com internamento',
#        'Percentagem de episódios de urgência atendidos dentro do tempo de espera previsto no protocolo de triagem',
#        'Percentagem de doentes sinalizados para a RNCCI em tempo adequado',
#        'Percentagem de cirurgias da anca efetuadas nas primeiras 48h'],
#       dtype=object)

# %%
df_ocupacao = df_aux[df_aux.Indicador == "Taxa de ocupação de bloco operatório"]
df_ocupacao
# Out:
#                                                 Hospital   Ano  Mes  \
# 52289            Centro Hospitalar Barreiro/Montijo, EPE  2014    6
# 52292            Centro Hospitalar Barreiro/Montijo, EPE  2014    9
# 52295            Centro Hospitalar Barreiro/Montijo, EPE  2014   12
# 52298            Centro Hospitalar Barreiro/Montijo, EPE  2015    3
# 52301            Centro Hospitalar Barreiro/Montijo, EPE  2015    6
# 52304            Centro Hospitalar Barreiro/Montijo, EPE  2015    9
# 52307            Centro Hospitalar Barreiro/Montijo, EPE  2015   12
# 52313                   Centro Hospitalar de Leiria, EPE  2014    6
# 52316                   Centro Hospitalar de Leiria, EPE  2014    9
# 52319                   Centro Hospitalar de Leiria, EPE  2014   12
# 52322                   Centro Hospitalar de Leiria, EPE  2015    3
# 52325                   Centro Hospitalar de Leiria, EPE  2015    6
# 52328                   Centro Hospitalar de Leiria, EPE  2015    9
# 52331                   Centro Hospitalar de Leiria, EPE  2015   12
# 52337         Centro Hospitalar de Lisboa Ocidental, EPE  2014    6
# 52340         Centro Hospitalar de Lisboa Ocidental, EPE  2014    9
# 52343         Centro Hospitalar de Lisboa Ocidental, EPE  2014   12
# 52346         Centro Hospitalar de Lisboa Ocidental, EPE  2015    3
# 52349         Centro Hospitalar de Lisboa Ocidental, EPE  2015    6
# 52352         Centro Hospitalar de Lisboa Ocidental, EPE  2015    9
# 52355         Centro Hospitalar de Lisboa Ocidental, EPE  2015   12
# 52361                  Centro Hospitalar de Setúbal, EPE  2014    6
# 52364                  Centro Hospitalar de Setúbal, EPE  2014    9
# 52367                  Centro Hospitalar de Setúbal, EPE  2014   12
# 52370                  Centro Hospitalar de Setúbal, EPE  2015    3
# 52373                  Centro Hospitalar de Setúbal, EPE  2015    6
# 52376                  Centro Hospitalar de Setúbal, EPE  2015    9
# 52379                  Centro Hospitalar de Setúbal, EPE  2015   12
# 52385                 Centro Hospitalar do Alto Ave, EPE  2014    6
# 52388                 Centro Hospitalar do Alto Ave, EPE  2014    9
# ...                                                  ...   ...  ...
# 56024          Unidade Local de Saúde do Alto Minho, EPE  2018    3
# 56027          Unidade Local de Saúde do Alto Minho, EPE  2018    6
# 56030          Unidade Local de Saúde do Alto Minho, EPE  2018    9
# 56033          Unidade Local de Saúde do Alto Minho, EPE  2018   12
# 56036          Unidade Local de Saúde do Alto Minho, EPE  2019    3
# 56039          Unidade Local de Saúde do Alto Minho, EPE  2019    6
# 56042          Unidade Local de Saúde do Alto Minho, EPE  2019    9
# 56045      Unidade Local de Saúde do Baixo Alentejo, EPE  2018    3
# 56048      Unidade Local de Saúde do Baixo Alentejo, EPE  2018    6
# 56051      Unidade Local de Saúde do Baixo Alentejo, EPE  2018    9
# 56060      Unidade Local de Saúde do Baixo Alentejo, EPE  2019    6
# 56063      Unidade Local de Saúde do Baixo Alentejo, EPE  2019    9
# 56066  Unidade Local de Saúde do Litoral Alentejano, EPE  2018    3
# 56072  Unidade Local de Saúde do Litoral Alentejano, EPE  2018    9
# 56075  Unidade Local de Saúde do Litoral Alentejano, EPE  2018   12
# 56078  Unidade Local de Saúde do Litoral Alentejano, EPE  2019    3
# 56087            Unidade Local de Saúde do Nordeste, EPE  2018    3
# 56090            Unidade Local de Saúde do Nordeste, EPE  2018    6
# 56093            Unidade Local de Saúde do Nordeste, EPE  2018    9
# 56096            Unidade Local de Saúde do Nordeste, EPE  2018   12
# 56099            Unidade Local de Saúde do Nordeste, EPE  2019    3
# 56102            Unidade Local de Saúde do Nordeste, EPE  2019    6
# 56105            Unidade Local de Saúde do Nordeste, EPE  2019    9
# 56108    Unidade Local de Saúde do Norte Alentejano, EPE  2018    3
# 56111    Unidade Local de Saúde do Norte Alentejano, EPE  2018    6
# 56114    Unidade Local de Saúde do Norte Alentejano, EPE  2018    9
# 56117    Unidade Local de Saúde do Norte Alentejano, EPE  2018   12
# 56120    Unidade Local de Saúde do Norte Alentejano, EPE  2019    3
# 56123    Unidade Local de Saúde do Norte Alentejano, EPE  2019    6
# 56126    Unidade Local de Saúde do Norte Alentejano, EPE  2019    9
#
#                                   Indicador Sub-indicador     Valor  \
# 52289  Taxa de ocupação de bloco operatório                0.527273
# 52292  Taxa de ocupação de bloco operatório                0.433333
# 52295  Taxa de ocupação de bloco operatório                0.540606
# 52298  Taxa de ocupação de bloco operatório                0.548788
# 52301  Taxa de ocupação de bloco operatório                0.530909
# 52304  Taxa de ocupação de bloco operatório                0.476364
# 52307  Taxa de ocupação de bloco operatório                0.435424
# 52313  Taxa de ocupação de bloco operatório                0.430652
# 52316  Taxa de ocupação de bloco operatório                0.446682
# 52319  Taxa de ocupação de bloco operatório                0.446970
# 52322  Taxa de ocupação de bloco operatório                0.445152
# 52325  Taxa de ocupação de bloco operatório                0.445152
# 52328  Taxa de ocupação de bloco operatório                0.400000
# 52331  Taxa de ocupação de bloco operatório                0.396970
# 52337  Taxa de ocupação de bloco operatório                0.485620
# 52340  Taxa de ocupação de bloco operatório                0.447851
# 52343  Taxa de ocupação de bloco operatório                0.442397
# 52346  Taxa de ocupação de bloco operatório                0.503554
# 52349  Taxa de ocupação de bloco operatório                0.504156
# 52352  Taxa de ocupação de bloco operatório                0.477922
# 52355  Taxa de ocupação de bloco operatório                0.461645
# 52361  Taxa de ocupação de bloco operatório                0.578182
# 52364  Taxa de ocupação de bloco operatório                0.577273
# 52367  Taxa de ocupação de bloco operatório                0.635682
# 52370  Taxa de ocupação de bloco operatório                0.515455
# 52373  Taxa de ocupação de bloco operatório                0.762114
# 52376  Taxa de ocupação de bloco operatório                0.590000
# 52379  Taxa de ocupação de bloco operatório                0.655227
# 52385  Taxa de ocupação de bloco operatório                0.459636
# 52388  Taxa de ocupação de bloco operatório                0.462727
# ...                                     ...           ...       ...
# 56024  Taxa de ocupação de bloco operatório                0.681403
# 56027  Taxa de ocupação de bloco operatório                0.652987
# 56030  Taxa de ocupação de bloco operatório                0.652987
# 56033  Taxa de ocupação de bloco operatório                0.652987
# 56036  Taxa de ocupação de bloco operatório                0.702597
# 56039  Taxa de ocupação de bloco operatório                0.690390
# 56042  Taxa de ocupação de bloco operatório                0.650130
# 56045  Taxa de ocupação de bloco operatório                0.664242
# 56048  Taxa de ocupação de bloco operatório                0.649697
# 56051  Taxa de ocupação de bloco operatório                0.485455
# 56060  Taxa de ocupação de bloco operatório                0.580606
# 56063  Taxa de ocupação de bloco operatório                0.580000
# 56066  Taxa de ocupação de bloco operatório                0.089091
# 56072  Taxa de ocupação de bloco operatório                0.089091
# 56075  Taxa de ocupação de bloco operatório                0.089091
# 56078  Taxa de ocupação de bloco operatório                0.089091
# 56087  Taxa de ocupação de bloco operatório                0.205000
# 56090  Taxa de ocupação de bloco operatório                0.334545
# 56093  Taxa de ocupação de bloco operatório                0.341818
# 56096  Taxa de ocupação de bloco operatório                0.337455
# 56099  Taxa de ocupação de bloco operatório                0.394545
# 56102  Taxa de ocupação de bloco operatório                0.380727
# 56105  Taxa de ocupação de bloco operatório                0.356364
# 56108  Taxa de ocupação de bloco operatório                0.249818
# 56111  Taxa de ocupação de bloco operatório                0.369418
# 56114  Taxa de ocupação de bloco operatório                0.352109
# 56117  Taxa de ocupação de bloco operatório                0.355382
# 56120  Taxa de ocupação de bloco operatório                0.400000
# 56123  Taxa de ocupação de bloco operatório                0.400000
# 56126  Taxa de ocupação de bloco operatório                0.365636
#
#                                                 Ficheiro
# 52289  1.6.Taxa de ocupação de Bloco Operatório_2014_...
# 52292  1.6.Taxa de ocupação de Bloco Operatório_2014_...
# 52295  1.6.Taxa de ocupação de Bloco Operatório_2014_...
# 52298  1.6.Taxa de ocupação de Bloco Operatório_2014_...
# 52301  1.6.Taxa de ocupação de Bloco Operatório_2014_...
# 52304  1.6.Taxa de ocupação de Bloco Operatório_2014_...
# 52307  1.6.Taxa de ocupação de Bloco Operatório_2014_...
# 52313  1.6.Taxa de ocupação de Bloco Operatório_2014_...
# 52316  1.6.Taxa de ocupação de Bloco Operatório_2014_...
# 52319  1.6.Taxa de ocupação de Bloco Operatório_2014_...
# 52322  1.6.Taxa de ocupação de Bloco Operatório_2014_...
# 52325  1.6.Taxa de ocupação de Bloco Operatório_2014_...
# 52328  1.6.Taxa de ocupação de Bloco Operatório_2014_...
# 52331  1.6.Taxa de ocupação de Bloco Operatório_2014_...
# 52337  1.6.Taxa de ocupação de Bloco Operatório_2014_...
# 52340  1.6.Taxa de ocupação de Bloco Operatório_2014_...
# 52343  1.6.Taxa de ocupação de Bloco Operatório_2014_...
# 52346  1.6.Taxa de ocupação de Bloco Operatório_2014_...
# 52349  1.6.Taxa de ocupação de Bloco Operatório_2014_...
# 52352  1.6.Taxa de ocupação de Bloco Operatório_2014_...
# 52355  1.6.Taxa de ocupação de Bloco Operatório_2014_...
# 52361  1.6.Taxa de ocupação de Bloco Operatório_2014_...
# 52364  1.6.Taxa de ocupação de Bloco Operatório_2014_...
# 52367  1.6.Taxa de ocupação de Bloco Operatório_2014_...
# 52370  1.6.Taxa de ocupação de Bloco Operatório_2014_...
# 52373  1.6.Taxa de ocupação de Bloco Operatório_2014_...
# 52376  1.6.Taxa de ocupação de Bloco Operatório_2014_...
# 52379  1.6.Taxa de ocupação de Bloco Operatório_2014_...
# 52385  1.6.Taxa de ocupação de Bloco Operatório_2014_...
# 52388  1.6.Taxa de ocupação de Bloco Operatório_2014_...
# ...                                                  ...
# 56024  1.6.Taxa de ocupação de Bloco Operatório_2014_...
# 56027  1.6.Taxa de ocupação de Bloco Operatório_2014_...
# 56030  1.6.Taxa de ocupação de Bloco Operatório_2014_...
# 56033  1.6.Taxa de ocupação de Bloco Operatório_2014_...
# 56036  1.6.Taxa de ocupação de Bloco Operatório_2014_...
# 56039  1.6.Taxa de ocupação de Bloco Operatório_2014_...
# 56042  1.6.Taxa de ocupação de Bloco Operatório_2014_...
# 56045  1.6.Taxa de ocupação de Bloco Operatório_2014_...
# 56048  1.6.Taxa de ocupação de Bloco Operatório_2014_...
# 56051  1.6.Taxa de ocupação de Bloco Operatório_2014_...
# 56060  1.6.Taxa de ocupação de Bloco Operatório_2014_...
# 56063  1.6.Taxa de ocupação de Bloco Operatório_2014_...
# 56066  1.6.Taxa de ocupação de Bloco Operatório_2014_...
# 56072  1.6.Taxa de ocupação de Bloco Operatório_2014_...
# 56075  1.6.Taxa de ocupação de Bloco Operatório_2014_...
# 56078  1.6.Taxa de ocupação de Bloco Operatório_2014_...
# 56087  1.6.Taxa de ocupação de Bloco Operatório_2014_...
# 56090  1.6.Taxa de ocupação de Bloco Operatório_2014_...
# 56093  1.6.Taxa de ocupação de Bloco Operatório_2014_...
# 56096  1.6.Taxa de ocupação de Bloco Operatório_2014_...
# 56099  1.6.Taxa de ocupação de Bloco Operatório_2014_...
# 56102  1.6.Taxa de ocupação de Bloco Operatório_2014_...
# 56105  1.6.Taxa de ocupação de Bloco Operatório_2014_...
# 56108  1.6.Taxa de ocupação de Bloco Operatório_2014_...
# 56111  1.6.Taxa de ocupação de Bloco Operatório_2014_...
# 56114  1.6.Taxa de ocupação de Bloco Operatório_2014_...
# 56117  1.6.Taxa de ocupação de Bloco Operatório_2014_...
# 56120  1.6.Taxa de ocupação de Bloco Operatório_2014_...
# 56123  1.6.Taxa de ocupação de Bloco Operatório_2014_...
# 56126  1.6.Taxa de ocupação de Bloco Operatório_2014_...
#
# [1005 rows x 7 columns]

# %%
def hospital_name_clean(string_series, conversion_dict=None):
    
    new_series = string_series.copy()
    
    # Make sure it is a string!
    new_series = new_series.astype(str)
    
    # lowercase
    new_series = new_series.str.lower()
    
    
    # Retira os acentos e cedilhas
    if conversion_dict != None:
        new_series = new_series.str.translate(conversion_dict)
        
    # remove or replace special characters
    new_series = new_series.str.replace(r'[^a-zA-Z0-9]', r' ',regex=True)
    
    
    # remover expressões mais frequentes
    remove_list = [r'\sde\s', 
                   r'\sdo\s', 
                   r'\sda\s', 
                   r'\se\s', 
                   r'hospital\s', 
                   r'^h\s',
                   r'\sh\s',
                   r'ch\s', 
                   r'^c\s',
                   r'\sc\s',
                   r'centro hospitalar',
                   r'unidade local saude',
                   r'distrital',
                   r'uls\s',
                   r'epe\s',
                   r'epe$']
    for word in remove_list:
        new_series = new_series.str.replace(word, ' ',regex=True)
    
    
    # remove or replace special characters
    new_series = new_series.str.replace(r' +', r' ',regex=True)
        
    # Trim
    new_series = new_series.str.strip()
    
    return new_series

# %%
hospital_name_clean(nomes_hosp.nome_original, conversion_dict=create_conversion_lower_case_dict())
# Out:
# 0                                 medio ave
# 1                                     oeste
# 2                   povoa varzim vila conde
# 3                              figueira foz
# 4                         santa maria maior
# 5                               baixo vouga
# 6                                cova beira
# 7                                    leiria
# 8                                   setubal
# 9                          barreiro montijo
# 10                               medio tejo
# 11                        entre douro vouga
# 12                             tamega sousa
# 13               senhora oliveira guimaraes
# 14                                 santarem
# 15                tras os montes alto douro
# 16                   vila nova gaia espinho
# 17                                  algarve
# 18                            tondela viseu
# 19                                    braga
# 20                           espirito santo
# 21                              garcia orta
# 22        professor doutor fernando fonseca
# 23                    universitario coimbra
# 24                         lisboa ocidental
# 25                   universitario sao joao
# 26                      universitario porto
# 27             universitario lisboa central
# 28               universitario lisboa norte
# 29    instituto portugues oncologia coimbra
# 30     instituto portugues oncologia lisboa
# 31      instituto portugues oncologia porto
# 32                          magalhaes lemos
# 33                                   guarda
# 34                           castelo branco
# 35                                 nordeste
# 36                       litoral alentejano
# 37                           baixo alentejo
# 38                               matosinhos
# 39                               alto minho
# 40                         norte alentejano
# Name: nome_original, dtype: object

# %%
df_all.Hospital.unique().size
# Out:
# 252

# %%
series_hospital_name = hospital_name_clean(df_all.Hospital, conversion_dict=create_conversion_lower_case_dict())

# %%
series_hospital_name.unique().size
# Out:
# 188

# %%
series_hospital_name.value_counts(dropna=False)
# Out:
# espirito santo evora                                     2364
# tondela viseu                                            2359
# castelo branco                                           2356
# lisboa ocidental                                         2352
# barreiro montijo                                         2351
# matosinhos                                               2346
# tamega sousa                                             2320
# baixo vouga                                              2302
# setubal                                                  2295
# guarda                                                   2287
# oeste                                                    2267
# leiria                                                   2223
# tras os montes alto douro                                2032
# universitario coimbra                                    2028
# garcia orta                                              2020
# distrital santarem                                       2010
# vila nova gaia espinho                                   2001
# alto minho                                               1993
# vila franca xira ppp                                     1989
# universitario porto                                      1982
# distrital figueira foz                                   1980
# baixo alentejo                                           1975
# medio ave                                                1974
# universitario algarve                                    1973
# litoral alentejano                                       1972
# universitario lisboa norte                               1967
# nordeste                                                 1966
# medio tejo                                               1950
# entre douro vouga                                        1937
# povoa varzim vila conde                                  1932
#                                                          ...
# luz                                                        72
# clinica montes claros                                      72
# porto epe hosp joaquim urbano                              71
# norte alentejo                                             71
# leiria pombal                                              71
# cuf santarem                                               70
# grupo f                                                    69
# grupo e                                                    69
# grupo a                                                    69
# grupo c                                                    69
# grupo b                                                    69
# grupo d                                                    69
# luz oeiras                                                 66
# scmp prelada                                               35
# jose luciano castro ipss                                   35
# arcebispo joao crisostomo cantanhede                       24
# clinica parque dos poetas                                  24
# centro medico reabilitacao regiao centro rovisco pais      24
# nao sns                                                    24
# clisa clinica st antonio                                   24
# porto                                                      24
# dr francisco zagalo ovar                                   24
# cascais dr jose almeida ppp                                24
# garcia orta epe almada                                     24
# beatriz angelo ppp loures                                  24
# cruz vermelha portuguesa                                   24
# instituto oftalmologia dr gama pinto                       24
# distrital santa maria maior epe barcelos                   24
# hp santarem                                                24
# n senhora oliveira epe guimaraes                           24
# Name: Hospital, Length: 188, dtype: int64

# %%
series_hospital_name.value_counts(dropna=False).to_excel("nomes_hospitais.xlsx")

# %%
nomes_hosp = pd.read_excel("hospitais.xlsx", sheet_name="nome original", header=[0])

# %%
hospital_name_clean(nomes_hosp.nome_original, conversion_dict=create_conversion_lower_case_dict()).to_excel("hospitais.xlsx", sheet_name="nome simplificado")

# %%
hospital_name_clean(nomes_hosp.nome_original, conversion_dict=create_conversion_lower_case_dict())
# Out:
# 0                                 medio ave
# 1                                     oeste
# 2                   povoa varzim vila conde
# 3                    distrital figueira foz
# 4                         santa maria maior
# 5                               baixo vouga
# 6                                cova beira
# 7                                    leiria
# 8                                   setubal
# 9                          barreiro montijo
# 10                               medio tejo
# 11                        entre douro vouga
# 12                             tamega sousa
# 13               senhora oliveira guimaraes
# 14                       distrital santarem
# 15                tras os montes alto douro
# 16                   vila nova gaia espinho
# 17                                  algarve
# 18                            tondela viseu
# 19                                    braga
# 20                           espirito santo
# 21                              garcia orta
# 22        professor doutor fernando fonseca
# 23                    universitario coimbra
# 24                         lisboa ocidental
# 25                   universitario sao joao
# 26                      universitario porto
# 27             universitario lisboa central
# 28               universitario lisboa norte
# 29    instituto portugues oncologia coimbra
# 30     instituto portugues oncologia lisboa
# 31      instituto portugues oncologia porto
# 32                          magalhaes lemos
# 33                                   guarda
# 34                           castelo branco
# 35                                 nordeste
# 36                       litoral alentejano
# 37                           baixo alentejo
# 38                               matosinhos
# 39                               alto minho
# 40                         norte alentejano
# Name: nome_original, dtype: object

# %%
df_clean[df_clean['Valor'].astype(str).str.contains(r'%', regex=True)]

# %%
df_clean['Valor'].astype(str).str.contains(r'[^0-9.,]', regex=True).sum()

# %%
df_clean['Valor'] = df_clean['Valor'].astype(str).str.replace(r'[^0-9.,]', r'',regex=True)

# %%
df_clean[df_clean['Valor'].astype(str).str.contains(r'[^0-9.,]', regex=True)]

# %%
df_clean['Valor'].head()

# %%
df_clean['Valor'].astype(str).str.replace(r'[^0-9.,]', r'',regex=True)

# %%
df_clean['Valor'].astype(str).str.contains("%").sum()

# %%
df_clean['Valor'].str.replace(r'\%', r' ',regex=True)

# %%
pd.to_numeric(df_clean['Valor'].str.replace('%', ' ',regex=True), errors='raise')

# %%
57686-564

# %%
df_clean[df_clean['Valor'].isna()]

# %%
df_all.shape

# %%
df_all.Hospital.isna().sum()

# %%
df_all[df_all.Hospital.isna()]

# %%
hospital_name_clean(df_all.Hospital, conversion_dict=create_conversion_lower_case_dict()).isna().sum()

# %%
hospital_name_clean(df_all.Hospital, conversion_dict=create_conversion_lower_case_dict()).shape

# %%
#df_final.astype({'Ano':int, 'Mes':int})

#df_final.to_excel("Dados consolidados.xlsx", index=False)

# %%
print("\u0394")

# %%
int("01705", 16)

# %%
chr(5893)

# %%
print("\u25F0")

# %%
print("\u0394")

# %%
"andá".encode('ascii', errors="ignore")

# %%
str(u'\u2167')

# %%
"À".casefold()

# %%
"À".lower()

# %%
translationTable = str.maketrans("éàèùâêîôûç", "eaeuaeiouc")

# %%
chr(int(unicodedata.decomposition("à").split()[0]))

# %%
a_chars_list = [chr(c) for c in range(224,231)]
e_chars_list = [chr(c) for c in range(232,236)]
i_chars_list = [chr(c) for c in range(236,240)]
o_chars_list = [chr(c) for c in range(242,247)]
u_chars_list = [chr(c) for c in range(242,247)]

# %%
a_chars_list = ['a'] + [chr(c) for c in range(224,231)]
a_chars_list

# %%
conversion_dict

# %%
a_list = ['a', 'à', 'á', 'â', 'ã', 'ä', 'å', 'æ']

# %%
len(''.join(a_list[1:]))

# %%
len(a_list[0]*len(a_list[1:]))

# %%
a_list = ['a', 'à', 'á', 'â', 'ã', 'ä', 'å', 'æ']
str.maketrans(''.join(a_list[1:]), a_list[0]*len(a_list[1:]))

# %%
create_conversion_lower_case_dict()

# %%
ord('ñ')

# %%
list(map(chr, range(256)))
